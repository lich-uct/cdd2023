# %%
from rdkit.Chem import AllChem as Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
import csv
import gzip

# %%
from rdkit import RDLogger
RDLogger.DisableLog("rdApp.error")

# %%
# load your own set, and DrugBank :)
with open("../data/drd3_chembl_cmpds.csv", 'r') as csvfile:
    reader = csv.DictReader(csvfile, delimiter=";")
    drd3 = [Chem.MolFromSmiles(m['Smiles']) for m in reader]


suppl = Chem.SDMolSupplier('../data/drugbank.sdf')
drugs = [m for m in suppl if m]

# open actives_final.sdf.gz and load the molecules
with gzip.open("../data/actives_final.sdf.gz", "r") as f:
    suppl = Chem.ForwardSDMolSupplier(f)
    actives = [m for m in suppl if m]

with gzip.open("../data/decoys_final.sdf.gz", "r") as f:
    suppl = Chem.ForwardSDMolSupplier(f)
    decoys = [m for m in suppl if m]

# %%
# from drugbank and actives find the one which have carboxylic acid in them


carboxy = Chem.MolFromSmarts('C(=O)[O;h1]')
carboxy.HasSubstructMatch(drugs[0])

# count the number of occurences of carboxylic acids drugbank
cooh_counts = [len(m.GetSubstructMatches(carboxy)) for m in drugs]
cooh_nonzero = [c for c in cooh_counts if c > 0]
len(cooh_counts), len(cooh_nonzero)
# Out:
# (7117, 1635)

# %%
# count the number of occurences of carboxylic acids in actives
cooh_counts = [len(m.GetSubstructMatches(carboxy)) for m in actives]
cooh_nonzero = [c for c in cooh_counts if c > 0]
len(cooh_counts), len(cooh_nonzero)
# Out:
# (877, 0)

# %%
# count the number of occurences of carboxylic acids in decoys
cooh_counts = [len(m.GetSubstructMatches(carboxy)) for m in decoys]
cooh_nonzero = [c for c in cooh_counts if c > 0]
len(cooh_counts), len(cooh_nonzero)
# Out:
# (34188, 1)

# %%
# now do it for all datasets with salicylic acid
salicylic = Chem.MolFromSmarts('c1ccc(c(c1)C(=O)O)O')

# count the number of occurences of salicylic acid in drugbank, actives and decoys
cooh_counts = [len(m.GetSubstructMatches(salicylic)) for m in drugs]
cooh_nonzero = [c for c in cooh_counts if c > 0]
print(f'Number of molecules in drugbank: {len(cooh_counts)}')
print(f'Number of molecules in drugbank with salicylic acid: {len(cooh_nonzero)}')
print('\n')


cooh_counts = [len(m.GetSubstructMatches(salicylic)) for m in actives]
cooh_nonzero = [c for c in cooh_counts if c > 0]
print(f'Number of molecules in actives: {len(cooh_counts)}')
print(f'Number of molecules in actives with salicylic acid: {len(cooh_nonzero)}')
print('\n')

cooh_counts = [len(m.GetSubstructMatches(salicylic)) for m in decoys]
cooh_nonzero = [c for c in cooh_counts if c > 0]
print(f'Number of molecules in decoys: {len(cooh_counts)}')
print(f'Number of molecules in decoys with salicylic acid: {len(cooh_nonzero)}')
print('\n')
# Out:
# Number of molecules in drugbank: 7117
# Number of molecules in drugbank with salicylic acid: 50
#
#
# Number of molecules in actives: 877
# Number of molecules in actives with salicylic acid: 0
#
#
# Number of molecules in decoys: 34188
# Number of molecules in decoys with salicylic acid: 17

# %%
# compute 2d coordinates for the molecules
for m in decoys_salicylic:
    Chem.Compute2DCoords(m)

# use the 2d coordinates to draw the molecules
Draw.MolsToGridImage(decoys_salicylic, molsPerRow=3, subImgSize=(300,300),
                        legends=["{} | {}".format(m.GetProp("_Name"), m.GetProp("_Name"))
                                    for m in decoys_salicylic])

# %%
# PAINS
from itertools import chain

# load PAINS structures in SMARTS format from two files in data
pains = []
with open('../data/pains/p_l15.txt', 'r') as f, open('../data/pains/p_m150.txt', 'r') as p:
    for line in chain(f, p):
        pattern, text = line.strip().split('\t') # split by tab
        pains.append([Chem.MolFromSmarts(pattern),
                      text.lstrip("<regId=\"").rstrip("\">")]) # remove the xml tags
pains, len(pains)
# Out:
# ([[<rdkit.Chem.rdchem.Mol at 0x7f1195f52260>, 'anil_di_alk_F(14)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f522d0>, 'hzone_anil(14)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52340>, 'het_5_pyrazole_OH(14)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f520a0>, 'het_thio_666_A(13)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52420>, 'styrene_A(13)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52490>, 'ne_rhod_C(13)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52500>, 'hp_amino_CN_A(13)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f525e0>, 'cyano_imine_C(12)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52570>, 'thio_urea_A(12)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52650>, 'thiophene_amino_B(12)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f526c0>, 'keto_keto_beta_B(12)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52730>, 'keto_phenone_A(11)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f527a0>, 'cyano_pyridone_C(11)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52810>, 'thiaz_ene_C(11)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52880>, 'hzone_thiophene_A(11)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f528f0>, 'ne_quin_methide(10)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52960>, 'het_thio_676_A(10)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f529d0>, 'ne_five_het_G(10)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52ab0>, 'acyl_het_A(9)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52a40>, 'anil_di_alk_G(9)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52b20>, 'hp_keto_A(9)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52b90>, 'thio_urea_B(9)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52c00>, 'anil_alk_bim(9)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52c70>, 'imine_imine_A(9)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52ce0>, 'thio_urea_C(9)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52dc0>, 'imine_one_fives_B(9)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52d50>, 'hp_amino_CN_B(9)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52e30>, 'anil_OC_no_alk_A(8)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52f10>, 'het_thio_66_one(8)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52ea0>, 'styrene_B(8)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52f80>, 'het_thio_5_A(8)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f52ff0>, 'anil_di_alk_ene_A(8)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53060>, 'ne_rhod_D(8)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f530d0>, 'ne_rhod_E(8)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53140>, 'anil_OH_alk_A(8)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53220>, 'pyrrole_C(8)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f531b0>, 'thio_urea_D(8)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53300>, 'thiaz_ene_D(8)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53290>, 'ne_rhod_F(8)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53370>, 'thiaz_ene_E(8)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f533e0>, 'het_65_B(7)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f534c0>, 'keto_keto_beta_C(7)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53450>, 'het_66_A(7)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53530>, 'thio_urea_E(7)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f535a0>, 'thiophene_amino_C(7)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53610>, 'hzone_phenone(7)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53680>, 'ne_rhod_G(7)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f536f0>, 'ne_cyano_B(7)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53760>, 'hp_amino_CN_C(7)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f537d0>, 'het_5_A(7)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53840>, 'ne_five_het_H(6)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f538b0>, 'thio_amide_A(6)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53990>, 'ne_cyano_C(6)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53920>, 'hzone_furan_A(6)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53a00>, 'anil_di_alk_H(6)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53a70>, 'het_65_C(6)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53b50>, 'thio_urea_F(6)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53ae0>, 'ne_five_het_I(6)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53c30>, 'keto_keto_gamma(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53bc0>, 'quinone_B(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53ca0>, 'het_6_pyridone_OH(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53d10>, 'hzone_naphth_A(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53df0>, 'thio_ester_A(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53d80>, 'ne_misc_A(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53ed0>, 'cyano_pyridone_D(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53e60>, 'het_65_Db(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc040>, 'het_666_A(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195f53f40>, 'iazox_sulfon_B(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc0b0>, 'anil_NH_alk_A(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc120>, 'sulfonamide_C(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc190>, 'het_thio_N_55(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc200>, 'keto_keto_beta_D(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc270>, 'ne_rhod_H(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc2e0>, 'imine_ene_A(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc350>, 'het_thio_656a(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc3c0>, 'pyrrole_D(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc430>, 'pyrrole_E(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc4a0>, 'thio_urea_G(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc510>, 'anisol_A(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc580>, 'pyrrole_F(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc5f0>, 'hp_amino_CN_D(5)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc6d0>, 'thiazole_amine_A(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc660>, 'het_6_imidate_A(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc740>, 'anil_OC_no_alk_B(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc820>, 'styrene_C(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc7b0>, 'azulene(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc890>, 'furan_acid_A(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc900>, 'cyano_pyridone_E(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc970>, 'anil_alk_thio(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdc9e0>, 'anil_di_alk_I(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdca50>, 'het_thio_6_furan(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdcac0>, 'anil_di_alk_ene_B(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdcb30>, 'imine_one_B(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdcba0>, 'anil_OC_alk_A(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdcc10>, 'ne_five_het_J(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdcc80>, 'pyrrole_G(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdccf0>, 'ne_five_het_K(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdcd60>, 'cyano_ene_amine_B(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdcdd0>, 'thio_ester_B(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdce40>, 'ne_five_het_L(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdceb0>, 'hzone_thiophene_B(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdcf20>, 'hp_amino_CN_E(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdcf90>, 'het_5_B(4)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd070>, 'imine_imine_B(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd000>, 'thiazole_amine_B(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd150>, 'imine_ene_one_A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd0e0>, 'iazox_A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd1c0>, 'ne_one_A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd230>, 'anil_OC_no_alk_C(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd310>, 'thiazol_SC_A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd2a0>, 'het_666_B(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd380>, 'furan_A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd460>, 'colchicine_A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd3f0>, 'thiophene_C(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd4d0>, 'anil_OC_alk_B(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd540>, 'het_thio_66_A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd5b0>, 'hod_sat_B(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd620>, 'ne_rhod_I(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd690>, 'keto_thiophene(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd700>, 'imine_imine_C(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd770>, 'het_65_pyridone_A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd7e0>, 'thiazole_amine_C(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd850>, 'het_thio_pyr_A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd8c0>, 'melamine_A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd930>, 'anil_NH_alk_B(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdd9a0>, 'hod_sat_C(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdda10>, 'thiophene_amino_D(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdda80>, 'anil_OC_alk_C(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fddaf0>, 'het_thio_65_A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fddb60>, 'het_thio_656b(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fddbd0>, 'thiazole_amine_D(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fddc40>, 'thio_urea_H(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fddcb0>, 'cyano_pyridone_F(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fddd20>, 'hod_sat_D(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fddd90>, 'ne_rhod_J(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdde00>, 'imine_phenol_A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdde70>, 'thio_carbonate_B(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fddf50>, 'het_thio_N_5A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fddfc0>, 'het_thio_N_65A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fddee0>, 'anil_di_alk_J(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde0a0>, 'pyrrole_H(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde030>, 'ne_cyano_D(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde110>, 'cyano_cyano_B(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde180>, 'ne_five_het_M(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde1f0>, 'cyano_ene_amine_C(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde260>, 'thio_urea_I(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde2d0>, 'hp_amino_CN_F(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde340>, 'anthranil_acid_B(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde420>, 'iazox_B(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde3b0>, 'thio_aldehyd_A(3)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde490>, 'thio_amide_B(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde500>, 'imidazole_B(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde570>, 'thiazole_amine_E(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde650>, 'thiazole_amine_F(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde5e0>, 'thio_ester_C(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde6c0>, 'ne_one_B(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde730>, 'quinone_C(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde7a0>, 'keto_naphthol_A(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde810>, 'thio_amide_C(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde880>, 'phthalimide_misc(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde8f0>, 'sulfonamide_D(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde960>, 'anil_NH_alk_C(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fde9d0>, 'het_65_E(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdea40>, 'hzide_naphth(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdeab0>, 'anisol_B(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdeb20>, 'thio_carbam_ene(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdeb90>, 'thio_amide_D(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdec70>, 'het_65_Da(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdec00>, 'thiophene_D(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fded50>, 'het_thio_6_ene(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdece0>, 'cyano_keto_A(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdedc0>, 'anthranil_acid_C(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdeea0>, 'naphth_amino_C(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdee30>, 'naphth_amino_D(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdef10>, 'thiazole_amine_G(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdef80>, 'het_66_B(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdeff0>, 'coumarin_A(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf0d0>, 'anthranil_acid_D(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf060>, 'het_66_C(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf1b0>, 'thiophene_amino_E(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf140>, 'het_6666_A(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf220>, 'sulfonamide_E(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf290>, 'anil_di_alk_K(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf300>, 'het_5_C(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf370>, 'ne_six_het_B(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf3e0>, 'steroid_A(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf450>, 'het_565_A(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf530>, 'thio_imine_ium(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf4c0>, 'anthranil_acid_E(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf5a0>, 'hzone_furan_B(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf610>, 'thiophene_E(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf680>, 'ne_misc_B(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf760>, 'het_thio_5_B(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf6f0>, 'thiophene_amino_F(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf7d0>, 'anil_OC_alk_D(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf840>, 'tert_butyl_A(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf8b0>, 'thio_urea_J(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf990>, 'het_thio_65_B(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdf920>, 'coumarin_B(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdfa00>, 'thio_urea_K(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdfa70>, 'thiophene_amino_G(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdfae0>, 'anil_NH_alk_D(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdfb50>, 'het_thio_5_C(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdfbc0>, 'thio_keto_het(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdfc30>, 'het_thio_N_5B(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdfd10>, 'quinone_D(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdfca0>, 'anil_di_alk_furan_B(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdfdf0>, 'ne_six_het_C(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdfd80>, 'het_55_A(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdfe60>, 'het_thio_65_C(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdfed0>, 'hydroquin_A(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fdff40>, 'anthranil_acid_F(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0040>, 'pyrrole_I(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe00b0>, 'thiophene_amino_H(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0120>, 'imine_one_fives_C(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0190>, 'keto_phenone_zone_A(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0200>, 'yes7A(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0270>, 'het_pyridiniums_B(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe02e0>, 'het_5_D(2)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0350>, 'thiazole_amine_H(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe03c0>, 'thiazole_amine_I(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0430>, 'het_thio_N_5C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0510>, 'sulfonamide_F(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe04a0>, 'thiazole_amine_J(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0580>, 'het_65_F(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe05f0>, 'keto_keto_beta_E(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0660>, 'ne_five_one_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe06d0>, 'keto_keto_beta_zone(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0740>, 'thio_urea_L(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe07b0>, 'het_thio_urea_ene(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0820>, 'cyano_amino_het_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0890>, 'tetrazole_hzide(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0900>, 'imine_naphthol_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0970>, 'misc_anisole_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0a50>, 'het_thio_665(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe09e0>, 'anil_di_alk_L(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0ac0>, 'colchicine_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0b30>, 'misc_aminoacid_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0ba0>, 'imidazole_amino_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0c10>, 'phenol_sulfite_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0c80>, 'het_66_D(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0cf0>, 'misc_anisole_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0d60>, 'tetrazole_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0dd0>, 'het_65_G(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0e40>, 'misc_trityl_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0eb0>, 'misc_pyridine_OC(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0f20>, 'het_6_hydropyridone(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe0f90>, 'misc_stilbene(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1000>, 'misc_imidazole(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1070>, 'anil_NH_no_alk_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe10e0>, 'het_6_imidate_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1150>, 'anil_alk_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe11c0>, 'styrene_anil_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1230>, 'misc_aminal_acid(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe12a0>, 'anil_no_alk_D(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1310>, 'anil_alk_C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1380>, 'misc_anisole_C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1460>, 'het_465_misc(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe13f0>, 'anthranil_acid_G(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe14d0>, 'anil_di_alk_M(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1540>, 'anthranil_acid_H(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe15b0>, 'thio_urea_M(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1620>, 'thiazole_amine_K(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1690>, 'het_thio_5_imine_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1700>, 'thio_amide_E(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1770>, 'het_thio_676_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe17e0>, 'sulfonamide_G(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1850>, 'thio_thiomorph_Z(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe18c0>, 'naphth_ene_one_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1930>, 'naphth_ene_one_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1a10>, 'amino_acridine_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe19a0>, 'keto_phenone_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1a80>, 'hzone_acid_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1af0>, 'sulfonamide_H(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1b60>, 'het_565_indole(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1bd0>, 'pyrrole_J(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1c40>, 'pyrazole_amino_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1cb0>, 'pyrrole_K(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1d20>, 'anthranil_acid_I(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1e00>, 'thio_amide_F(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1d90>, 'ne_one_C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1ee0>, 'het_65_H(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1e70>, 'cyano_imine_D(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1f50>, 'cyano_misc_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe1fc0>, 'ne_misc_C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2030>, 'het_66_E(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe20a0>, 'keto_keto_beta_F(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2110>, 'misc_naphthimidazole(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe21f0>, 'naphth_ene_one_C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2180>, 'keto_phenone_C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe22d0>, 'coumarin_C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2260>, 'thio_est_cyano_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2340>, 'het_65_imidazole(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe23b0>, 'anthranil_acid_J(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2420>, 'colchicine_het(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2490>, 'ne_misc_D(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2500>, 'indole_3yl_alk_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2570>, 'anil_OH_no_alk_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2650>, 'thiazole_amine_L(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe25e0>, 'pyrazole_amino_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2730>, 'het_thio_N_5D(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe26c0>, 'anil_alk_indane(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe27a0>, 'anil_di_alk_N(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2810>, 'het_666_C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe28f0>, 'ne_one_D(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2880>, 'anil_di_alk_indol(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2960>, 'anil_no_alk_indol_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe29d0>, 'hp_amino_CN_G(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2a40>, 'anil_di_alk_dhp(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2ab0>, 'anthranil_amide_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2b20>, 'hzone_anthran_Z(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2b90>, 'ne_one_amide_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2c00>, 'het_76_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2c70>, 'thio_urea_N(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2ce0>, 'anil_di_alk_coum(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2d50>, 'ne_one_amide_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2dc0>, 'het_thio_656c(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2e30>, 'het_5_ene(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2ea0>, 'thio_imide_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2f10>, 'hp_amidine_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2f80>, 'thio_urea_O(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe2ff0>, 'anil_di_alk_O(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3060>, 'thio_urea_P(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe30d0>, 'het_pyraz_misc(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3140>, 'iazox_C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe31b0>, 'iazox_D(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3220>, 'misc_cyclopropane(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3290>, 'imine_ene_one_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3300>, 'coumarin_D(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3370>, 'misc_furan_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe33e0>, 'hod_sat_E(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3450>, 'hod_sat_imine_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe34c0>, 'hod_sat_F(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3530>, 'het_thio_5_imine_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe35a0>, 'het_thio_5_imine_C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3610>, 'ne_five_het_N(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3680>, 'thio_carbam_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe36f0>, 'misc_anilide_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3760>, 'misc_anilide_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe37d0>, 'mannich_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3840>, 'mannich_catechol_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe38b0>, 'anil_alk_D(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3920>, 'het_65_I(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3990>, 'misc_urea_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3a00>, 'imidazole_C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3a70>, 'styrene_imidazole_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3ae0>, 'thiazole_amine_M(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3b50>, 'misc_pyrrole_thiaz(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3bc0>, 'pyrrole_L(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3c30>, 'het_thio_65_D(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3ca0>, 'ne_misc_E(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3d10>, 'thio_cyano_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3d80>, 'cyano_amino_het_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3df0>, 'cyano_pyridone_G(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3e60>, 'het_65_J(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3f40>, 'ne_one_yne_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe3ed0>, 'anil_OH_no_alk_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4040>, 'hzone_acyl_misc_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe40b0>, 'thiophene_F(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4120>, 'anil_OC_alk_E(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4190>, 'anil_OC_alk_F(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4200>, 'het_65_K(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4270>, 'het_65_L(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe42e0>, 'coumarin_E(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4350>, 'coumarin_F(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe43c0>, 'coumarin_G(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4430>, 'coumarin_H(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe44a0>, 'het_thio_67_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4510>, 'sulfonamide_I(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4580>, 'het_65_mannich(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe45f0>, 'anil_alk_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4660>, 'het_5_inium(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe46d0>, 'anil_di_alk_P(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4740>, 'thio_urea_Q(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe47b0>, 'thio_pyridine_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4820>, 'melamine_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4890>, 'misc_phthal_thio_N(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4900>, 'hzone_acyl_misc_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4970>, 'tert_butyl_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe49e0>, 'iazox_E(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4a50>, 'anil_NH_no_alk_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4ac0>, 'anil_no_alk_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4b30>, 'anil_no_alk_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4ba0>, 'thio_ene_amine_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4c10>, 'het_55_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4c80>, 'cyanamide_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4cf0>, 'ne_one_one_A(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4dd0>, 'ne_six_het_D(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4d60>, 'ne_cyano_E(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4e40>, 'ne_cyano_F(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4eb0>, 'hzone_furan_C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4f20>, 'anil_no_alk_C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe4f90>, 'hzone_acid_D(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5000>, 'hzone_furan_E(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5070>, 'het_6_pyridone_NH2(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5150>, 'imine_one_fives_D(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe50e0>, 'pyrrole_M(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe51c0>, 'pyrrole_N(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5230>, 'pyrrole_O(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe52a0>, 'ne_cyano_G(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5310>, 'sulfonamide_J(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5380>, 'misc_pyrrole_benz(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe53f0>, 'thio_urea_R(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5460>, 'ne_one_one_B(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe54d0>, 'hp_amino_CN_H(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5540>, 'het_66_anisole(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe55b0>, 'thiazole_amine_N(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5620>, 'het_pyridiniums_C(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5690>, 'het_5_E(1)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5700>, 'ne_six_het_A(483)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5770>, 'hzone_phenol_A(479)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe57e0>, 'anil_di_alk_A(478)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5850>, 'indol_3yl_alk(461)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5930>, 'quinone_A(370)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe58c0>, 'azo_A(324)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe59a0>, 'imine_one_A(321)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5a10>, 'mannich_A(296)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5af0>, 'anil_di_alk_B(251)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5a80>, 'anil_di_alk_C(246)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5bd0>, 'ne_rhod_A(235)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5b60>, 'hzone_phenol_B(215)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5c40>, 'ne_five_het_A(201)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5cb0>, 'anil_di_alk_D(198)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5d90>, 'imine_one_isatin(189)'],
#   [<rdkit.Chem.rdchem.Mol at 0x7f1195fe5d20>, 'anil_di_alk_E(186)']],
#  425)

# %%
# scan drugbang, actives and decoys for PAINS
for m in drugs:
    m.pain_matches = [p for p, pain in enumerate(pains) if m.HasSubstructMatch(pain[0])]

for m in actives:
    m.pain_matches = [p for p, pain in enumerate(pains) if m.HasSubstructMatch(pain[0])]

for m in decoys:
    m.pain_matches = [p for p, pain in enumerate(pains) if m.HasSubstructMatch(pain[0])]

print(f'Number of molecules with PAINS in drugbank: {len([m for m in drugs if len(m.pain_matches) > 0])}')
print(f'Number of molecules with PAINS in actives: {len([m for m in actives if len(m.pain_matches) > 0])}')
print(f'Number of molecules with PAINS in decoys: {len([m for m in decoys if len(m.pain_matches) > 0])}')
# Out:
# Number of molecules with PAINS in drugbank: 125
# Number of molecules with PAINS in actives: 11
# Number of molecules with PAINS in decoys: 783

# %%
actives_with_pains = [m for m in actives if len(m.pain_matches) > 0]
actives_with_pains
# Out:
# [<rdkit.Chem.rdchem.Mol at 0x7f11b4e55ee0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f11b4e55fc0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f11b49ac120>,
#  <rdkit.Chem.rdchem.Mol at 0x7f11b49ac190>,
#  <rdkit.Chem.rdchem.Mol at 0x7f11b47947b0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f11b4794f20>,
#  <rdkit.Chem.rdchem.Mol at 0x7f11b4794f90>,
#  <rdkit.Chem.rdchem.Mol at 0x7f11b479a9d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f11b479aa40>,
#  <rdkit.Chem.rdchem.Mol at 0x7f11b479aab0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f11b479b060>]

# %%
# compute 2d coordinates for the molecules
for m in actives_with_pains:    
    Chem.Compute2DCoords(m)
    

# add PAINs names to the image
Draw.MolsToGridImage(actives_with_pains, molsPerRow=3, subImgSize=(300,300),
                        legends=["{} | {}".format(m.GetProp("_Name"), ", ".join([pains[p][1] for p in m.pain_matches]))
                                    for m in actives_with_pains])
