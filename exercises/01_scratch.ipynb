# %%
from rdkit import Chem
import pandas as pd

# %%
Chem.MolFromSmiles('c1ccccc1C')

# %%
df = pd.read_csv('../data/rock1/rock1_ic50_chembl.csv', sep=';')
df
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0         CHEMBL1089082           NaN                   0            459.43
# 1          CHEMBL466496           NaN                   0            293.33
# 2          CHEMBL559147       Y-27632                   0            247.34
# 3          CHEMBL604060           NaN                   0            440.57
# 4          CHEMBL595684           NaN                   0            450.54
# ...                 ...           ...                 ...               ...
# 1426      CHEMBL4785041           NaN                   0            360.41
# 1427      CHEMBL4585481           NaN                   0            419.53
# 1428      CHEMBL4538174          ERKi                   0            311.35
# 1429      CHEMBL4784425           NaN                   0            357.80
# 1430      CHEMBL4797055           NaN                   0            346.39
#
#      #RO5 Violations AlogP Compound Key  \
# ...

# %%
import gzip

# %%
with gzip.open('../fulopj/data/actives_final.sdf.gz', 'r') as sdf:
    suppl = Chem.ForwardSDMolSupplier(sdf)
    for mol in suppl:
        print(Chem.MolToSmiles(mol))
# Out:
# COc1cc(NC(=O)C2CC2)c(Cl)cc1C(=O)NC1CC[NH+](C2CCCCC2)C1
# CC(C)(C)c1nc(N2CC[NH+](CCCCN3C(=O)CCCc4c(O)cccc43)CC2)cc(C(F)(F)F)n1
# CC(C)(C)c1nc(N2CCN(CCCCN3C(=O)CCCc4c(O)cccc43)CC2)cc(C(F)(F)F)n1
# O=C(NCCCC[NH+]1CCN(C(c2ccccc2)c2ccccc2)CC1)c1cccs1
# O=C(NCCCC[NH+]1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1)c1ccc2ccccc2c1
# O=C(NCCCC[NH+]1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1)c1ccc2ccccc2c1
# O=C(/C=C/c1ccccc1)NCCCC[NH+]1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1
# O=C(/C=C/c1ccccc1)NCCCC[NH+]1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1
# CC(C)c1ccc(S(=O)(=O)Cc2ccc(C34C[NH2+]CC3C4)cc2)cc1
# CC(C)c1ccc(CS(=O)(=O)c2ccc(C34C[NH2+]CC3C4)cc2)cc1
# COc1cccc2c1C1CCN(CCCCNC(=O)C3=NCc4ccccc4C3)CC1=N2
# COc1cccc2c1C1CC[NH+](CCCCNC(=O)C3=NCc4ccccc4C3)CC1=N2
# COc1cccc2c1C1CCN(CCCCNC(=O)C3=NCc4ccccc4C3)CC1=N2
# COc1cccc2c1C1CC[NH+](CCCCNC(=O)C3=NCc4ccccc4C3)CC1=N2
# C1=[N+](CCc2c[nH]c3ncccc23)CCC(c2ccccc2)C1
# C1=[N+](CCc2c[nH]c3ncccc23)CCC(c2ccccc2)C1
# O=C(NCCCC[NH+]1CCN(c2cccc(Cl)c2Cl)CC1)c1cc2ccccc2cn1
# ...
