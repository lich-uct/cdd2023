# %% [markdown]
# # Dockstring
#
# - tool wrapped around AutoDock to fully automate docking process pipeline, SMILES to docking score
# - available at https://github.com/dockstring/dockstring , follow the install instructions, requires OpenBabel

# %%
from rdkit import Chem
from rdkit.Chem.SaltRemover import SaltRemover
from rdkit.Chem import Lipinski
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem import Descriptors

import dockstring

import re
import csv
import pandas as pd
import numpy as np
import gzip

# %% [markdown]
# # Standardization

# %%
""" contribution from Hans de Winter """
def _InitialiseNeutralisationReactions():
    patts= (
        # Imidazoles
        ('[n+;H]','n'),
        # Amines
        ('[N+;!H0]','N'),
        # Carboxylic acids and alcohols
        ('[$([O-]);!$([O-][#7])]','O'),
        # Thiols
        ('[S-;X1]','S'),
        # Sulfonamides
        ('[$([N-;X2]S(=O)=O)]','N'),
        # Enamines
        ('[$([N-;X2][C,N]=C)]','N'),
        # Tetrazoles
        ('[n-]','[nH]'),
        # Sulfoxides
        ('[$([S-]=O)]','S'),
        # Amides
        ('[$([N-]C=O)]','N'),
        )
    return [(Chem.MolFromSmarts(x),Chem.MolFromSmiles(y,False)) for x,y in patts]

_reactions=None
def NeutraliseCharges(mol, reactions=None):
    global _reactions
    if reactions is None:
        if _reactions is None:
            _reactions=_InitialiseNeutralisationReactions()
        reactions=_reactions
    replaced = False
    for i,(reactant, product) in enumerate(reactions):
        while mol.HasSubstructMatch(reactant):
            replaced = True
            rms = Chem.ReplaceSubstructs(mol, reactant, product)
            mol = rms[0]
    return mol, replaced

# %%
_saltRemover = SaltRemover()
_inorganicPatt = Chem.MolFromSmarts("[!#6;!#7;!#8;!#16;!F;!Cl;!Br;!I]") # to remove compounds with unwanted atom types
_carbonPatt = Chem.MolFromSmarts("[#6]") # to remove compounds without carbon - inorganic
def standardize(mol):
    if mol.HasSubstructMatch(_carbonPatt):
        mol = _saltRemover(mol)
        if mol.GetNumAtoms()==0:
            return None
        else:
            mol, neutralized = NeutraliseCharges(mol)
            if mol.HasSubstructMatch(_inorganicPatt):
                return None
            else:
                # Sanitize mol, without sanitization some structures can't be drawn or fingerprinted
                Chem.SanitizeMol(mol) # add catch block?
                return mol
    else:
        return None

# %% [markdown]
# # Data loading

# %%
mols = []

# %%
# some pChEMBL values in our file are not valid floats
float_pattern = re.compile("[0-9]+(\.[0-9]*)?")
# function for Lipinski's descriptors
# load rock1, we want to remember source of data and Standard and pChEMBLE value (it's transfomed compound activity to "standard" value)
with open("../data/rock1/rock1_ic50_chembl.csv") as inp:
    rock1 = [row for row in csv.DictReader(inp, delimiter=";", quotechar='"')]
    for m in rock1:
        moldict = {"smiles": m["Smiles"]}
        mol = Chem.MolFromSmiles(moldict["smiles"])
        if mol:
            moldict["rdmol"] = mol
            stdmol = standardize(mol)
            moldict["source"] = "rock1_chembl"
            moldict["pChEMBL Value"] = float(m["pChEMBL Value"]) if float_pattern.match(m["pChEMBL Value"]) else 0
            moldict["std_rdmol"] = None
            moldict["Standard Value"] = float(m["Standard Value"]) if float_pattern.match(m["Standard Value"]) else np.NaN
        if stdmol:
            moldict["std_rdmol"] = stdmol
            moldict["std_smiles"] = Chem.MolToSmiles(stdmol)
            mols.append(moldict)

# %%
mols
# Out:
# [{'smiles': 'O=C(Nc1cccc(-c2ccnc3cc(-c4ccncc4)nn23)c1)c1cccc(C(F)(F)F)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f16924d44e0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f91530>,
#   'Standard Value': 50000.0,
#   'std_smiles': 'O=C(Nc1cccc(-c2ccnc3cc(-c4ccncc4)nn23)c1)c1cccc(C(F)(F)F)c1'},
#  {'smiles': 'C[C@@H](Nc1c(Nc2ccncc2)c(=O)c1=O)c1ccccc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f91b20>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.22,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f92120>,
#   'Standard Value': 60.0,
#   'std_smiles': 'C[C@@H](Nc1c(Nc2ccncc2)c(=O)c1=O)c1ccccc1'},
#  {'smiles': 'C[C@@H](N)[C@H]1CC[C@H](C(=O)Nc2ccncc2)CC1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f92170>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.82,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f927b0>,
#   'Standard Value': 150.0,
#   'std_smiles': 'C[C@@H](N)[C@H]1CC[C@H](C(=O)Nc2ccncc2)CC1'},
#  {'smiles': 'Cc1n[nH]c2ccc(-c3cc(OC[C@@H](N)Cc4ccccc4)cnc3-c3ccsc3)cc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f92800>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.22,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f92df0>,
#   'Standard Value': 6000.0,
#   'std_smiles': 'Cc1n[nH]c2ccc(-c3cc(OC[C@@H](N)Cc4ccccc4)cnc3-c3ccsc3)cc12'},
#  {'smiles': 'Cc1n[nH]c2ccc(-c3cc(OC[C@@H](N)Cc4ccccc4)cnc3-c3cccc(O)c3)cc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f92e40>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f97490>,
#   'Standard Value': 10000.0,
#   'std_smiles': 'Cc1n[nH]c2ccc(-c3cc(OC[C@@H](N)Cc4ccccc4)cnc3-c3cccc(O)c3)cc12'},
#  {'smiles': 'Cc1c(-c2ccnc(N)n2)sc2ccc(C(N)c3cccc(O)c3)cc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f974e0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f97ad0>,
#   'Standard Value': 10.0,
#   'std_smiles': 'Cc1c(-c2ccnc(N)n2)sc2ccc(C(N)c3cccc(O)c3)cc12'},
#  {'smiles': 'Cc1c(-c2ccnc(N)n2)sc2ccc(CN)cc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f97b20>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.66,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f96170>,
#   'Standard Value': 2200.0,
#   'std_smiles': 'Cc1c(-c2ccnc(N)n2)sc2ccc(CN)cc12'},
#  {'smiles': 'CNC(C(=O)Nc1cc2cc[nH]c(=O)c2cc1Cl)c1ccccc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f961c0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.85,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f967b0>,
#   'Standard Value': 14.0,
#   'std_smiles': 'CNC(C(=O)Nc1cc2cc[nH]c(=O)c2cc1Cl)c1ccccc1'},
#  {'smiles': 'COc1cccc(CNC(=O)c2cc3ccc(-c4cn[nH]c4C)nc3[nH]2)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f96800>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.72,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f96df0>,
#   'Standard Value': 19.0,
#   'std_smiles': 'COc1cccc(CNC(=O)c2cc3ccc(-c4cn[nH]c4C)nc3[nH]2)c1'},
#  {'smiles': 'COc1ccc(OC)c(CNC(=O)c2c[nH]c3cc(-c4cn[nH]c4)ccc23)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f96e40>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.87,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f9f490>,
#   'Standard Value': 1340.0,
#   'std_smiles': 'COc1ccc(OC)c(CNC(=O)c2c[nH]c3cc(-c4cn[nH]c4)ccc23)c1'},
#  {'smiles': 'NCC1CCN(c2nc(-c3ccncc3)cnc2N2CCCC2)CC1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f9f4e0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.89,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f9fad0>,
#   'Standard Value': 130.0,
#   'std_smiles': 'NCC1CCN(c2nc(-c3ccncc3)cnc2N2CCCC2)CC1'},
#  {'smiles': 'CNCC1CCN(c2nc(-c3ccncc3)cnc2N2CCCC2)CC1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f9fb20>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.82,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2170>,
#   'Standard Value': 150.0,
#   'std_smiles': 'CNCC1CCN(c2nc(-c3ccncc3)cnc2N2CCCC2)CC1'},
#  {'smiles': 'c1cc(-c2cnc(N3CCCC3)c(N3CCNCC3)n2)c2cc[nH]c2n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa21c0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.47,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa27b0>,
#   'Standard Value': 34.0,
#   'std_smiles': 'c1cc(-c2cnc(N3CCCC3)c(N3CCNCC3)n2)c2cc[nH]c2n1'},
#  {'smiles': 'CCn1c(-c2nonc2N)nc2cncc(OCC3CCNCC3)c21',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2800>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.52,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2df0>,
#   'Standard Value': 3.0,
#   'std_smiles': 'CCn1c(-c2nonc2N)nc2cncc(OCC3CCNCC3)c21'},
#  {'smiles': 'COc1cccc(CNC(=O)c2c[nH]c3cc(-c4cn[nH]c4)ccc23)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2e40>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f9f670>,
#   'Standard Value': 1.0,
#   'std_smiles': 'COc1cccc(CNC(=O)c2c[nH]c3cc(-c4cn[nH]c4)ccc23)c1'},
#  {'smiles': 'COc1cccc(CNC(=O)c2cn(C)c3cc(-c4cn[nH]c4)ccc23)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f9f5d0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f96f80>,
#   'Standard Value': 1.0,
#   'std_smiles': 'COc1cccc(CNC(=O)c2cn(C)c3cc(-c4cn[nH]c4)ccc23)c1'},
#  {'smiles': 'CC1=C(C(=O)Nc2cc3cn[nH]c3cc2F)C(c2ccc(Cl)cc2F)N=C(c2ccnc(C)c2)N1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f96cb0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f96580>,
#   'Standard Value': 10.0,
#   'std_smiles': 'CC1=C(C(=O)Nc2cc3cn[nH]c3cc2F)C(c2ccc(Cl)cc2F)N=C(c2ccnc(C)c2)N1'},
#  {'smiles': 'CC1=C(C(=O)Nc2ccc3[nH]ncc3c2)C(c2ccc(F)cc2)N=C(c2cnccn2)N1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f96350>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.98,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f97e90>,
#   'Standard Value': 105.0,
#   'std_smiles': 'CC1=C(C(=O)Nc2ccc3[nH]ncc3c2)C(c2ccc(F)cc2)N=C(c2cnccn2)N1'},
#  {'smiles': 'COc1ccc(C2=NC(c3ccc(S(N)(=O)=O)cc3)C(C(=O)Nc3ccc4[nH]ncc4c3)=C(C)N2)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f97c60>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.17,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f972b0>,
#   'Standard Value': 68.0,
#   'std_smiles': 'COc1ccc(C2=NC(c3ccc(S(N)(=O)=O)cc3)C(C(=O)Nc3ccc4[nH]ncc4c3)=C(C)N2)cc1'},
#  {'smiles': 'Cc1c[nH]c2ncnc(N3CCN(C(=O)Nc4ccc(F)c(Br)c4)[C@@H](C)C3)c12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f97260>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.29,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f92d00>,
#   'Standard Value': 51.0,
#   'std_smiles': 'Cc1c[nH]c2ncnc(N3CCN(C(=O)Nc4ccc(F)c(Br)c4)[C@@H](C)C3)c12'},
#  {'smiles': 'NC[C@H](Cc1cccc(F)c1)NC(=O)c1cc(Br)c(-c2ccnc3[nH]ccc23)s1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f92b70>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.7,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f91f80>,
#   'Standard Value': 2.0,
#   'std_smiles': 'NC[C@H](Cc1cccc(F)c1)NC(=O)c1cc(Br)c(-c2ccnc3[nH]ccc23)s1'},
#  {'smiles': 'COc1ccc(C2=NC(C)C(C(=O)Nc3ccc4[nH]ncc4c3)=C(C)N2)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f91f30>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.06,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f91030>,
#   'Standard Value': 863.0,
#   'std_smiles': 'COc1ccc(C2=NC(C)C(C(=O)Nc3ccc4[nH]ncc4c3)=C(C)N2)cc1'},
#  {'smiles': 'COc1ccc2c(c1)C[C@H](C(=O)Nc1ccc(-c3cn[nH]c3)cc1OCCN(C)C)NC2',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f914e0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.32,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2670>,
#   'Standard Value': 48.0,
#   'std_smiles': 'COc1ccc2c(c1)C[C@H](C(=O)Nc1ccc(-c3cn[nH]c3)cc1OCCN(C)C)NC2'},
#  {'smiles': 'c1ccc2c(c1)CC(Nc1nc(Nc3ccncc3)nc(N3CCCCC3)n1)C2',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2620>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.08,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2f30>,
#   'Standard Value': 8300.0,
#   'std_smiles': 'c1ccc2c(c1)CC(Nc1nc(Nc3ccncc3)nc(N3CCCCC3)n1)C2'},
#  {'smiles': 'Cc1cnccc1-c1cnc(N)c(N2CCCN(C)CC2)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2f80>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa53a0>,
#   'Standard Value': 120000.0,
#   'std_smiles': 'Cc1cnccc1-c1cnc(N)c(N2CCCN(C)CC2)n1'},
#  {'smiles': 'CN1CCCN(c2nc(-c3ccc4[nH]ncc4c3)cnc2N)CC1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa53f0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.64,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa58f0>,
#   'Standard Value': 2300.0,
#   'std_smiles': 'CN1CCCN(c2nc(-c3ccc4[nH]ncc4c3)cnc2N)CC1'},
#  {'smiles': 'NC1CCN(c2nc(-c3ccncc3)cnc2N2CCCC2)CC1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa5940>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.54,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa5e40>,
#   'Standard Value': 290.0,
#   'std_smiles': 'NC1CCN(c2nc(-c3ccncc3)cnc2N2CCCC2)CC1'},
#  {'smiles': 'CN1CCN(Cc2ccc(-c3cnc4[nH]cc(-c5ccc6[nH]ccc6c5)c4c3)cc2)CC1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa5e90>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.99,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa63f0>,
#   'Standard Value': 1030.0,
#   'std_smiles': 'CN1CCN(Cc2ccc(-c3cnc4[nH]cc(-c5ccc6[nH]ccc6c5)c4c3)cc2)CC1'},
#  {'smiles': 'COc1cccc(CN(CCN2CCCC2)C(=O)c2cc3ccc(-c4cn[nH]c4)cc3[nH]2)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa6440>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.21,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa6940>,
#   'Standard Value': 62.0,
#   'std_smiles': 'COc1cccc(CN(CCN2CCCC2)C(=O)c2cc3ccc(-c4cn[nH]c4)cc3[nH]2)c1'},
#  {'smiles': 'Cc1coc2cc(OCC(=O)Nc3cccc(NC(=O)c4ccc(N(C)C)cc4)c3)ccc2c1=O',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa6990>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa6f80>,
#   'Standard Value': 10000.0,
#   'std_smiles': 'Cc1coc2cc(OCC(=O)Nc3cccc(NC(=O)c4ccc(N(C)C)cc4)c3)ccc2c1=O'},
#  {'smiles': 'CN(C)c1ccc(C(=O)Nc2cc(F)cc(NC(=O)COc3ccc4c(=O)ccoc4c3)c2)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faa030>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.31,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faa620>,
#   'Standard Value': 49.0,
#   'std_smiles': 'CN(C)c1ccc(C(=O)Nc2cc(F)cc(NC(=O)COc3ccc4c(=O)ccoc4c3)c2)cc1'},
#  {'smiles': 'CN(C)c1ccc(C(=O)Nc2cc(NC(=O)COc3ccc4c(=O)ccoc4c3)cc(C(F)(F)F)c2)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faa670>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faac60>,
#   'Standard Value': 10000.0,
#   'std_smiles': 'CN(C)c1ccc(C(=O)Nc2cc(NC(=O)COc3ccc4c(=O)ccoc4c3)cc(C(F)(F)F)c2)cc1'},
#  {'smiles': 'COc1cc(-c2cn[nH]c2)cc2c(=O)[nH]c([C@H](N)Cc3cccc(F)c3)nc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faacb0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.15,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fad300>,
#   'Standard Value': 7.0,
#   'std_smiles': 'COc1cc(-c2cn[nH]c2)cc2c(=O)[nH]c([C@H](N)Cc3cccc(F)c3)nc12'},
#  {'smiles': 'N[C@@H](Cc1ccc(Cl)cc1)c1nc2ccc(-c3cn[nH]c3)cc2c(=O)[nH]1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fad350>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fad940>,
#   'Standard Value': nan,
#   'std_smiles': 'N[C@@H](Cc1ccc(Cl)cc1)c1nc2ccc(-c3cn[nH]c3)cc2c(=O)[nH]1'},
#  {'smiles': 'c1ccc2c(c1)CC(Nc1nc(Nc3ccncc3)nc(N3CCCNCC3)n1)C2',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fad990>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.96,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fadf80>,
#   'Standard Value': 11.0,
#   'std_smiles': 'c1ccc2c(c1)CC(Nc1nc(Nc3ccncc3)nc(N3CCCNCC3)n1)C2'},
#  {'smiles': 'c1ccc2c(N3CCNCC3)nc(-c3ccc4[nH]ncc4c3)nc2c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fae030>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.41,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fae620>,
#   'Standard Value': 39.0,
#   'std_smiles': 'c1ccc2c(N3CCNCC3)nc(-c3ccc4[nH]ncc4c3)nc2c1'},
#  {'smiles': 'O=C(Nc1ccc(-c2ccncc2)cc1)N[C@H](CO)Cc1ccccc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fae670>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 4.51,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faec60>,
#   'Standard Value': 31010.0,
#   'std_smiles': 'O=C(Nc1ccc(-c2ccncc2)cc1)N[C@H](CO)Cc1ccccc1'},
#  {'smiles': 'Cc1c(-c2cc(N)ncn2)sc2ccc(Cl)cc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faecb0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 4.89,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb2300>,
#   'Standard Value': 13000.0,
#   'std_smiles': 'Cc1c(-c2cc(N)ncn2)sc2ccc(Cl)cc12'},
#  {'smiles': 'C[C@H]1COCCN1c1cc(-c2ccc3c(N)n[nH]c3c2)nc(N)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb2350>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 4.8,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb2940>,
#   'Standard Value': 15848.93,
#   'std_smiles': 'C[C@H]1COCCN1c1cc(-c2ccc3c(N)n[nH]c3c2)nc(N)n1'},
#  {'smiles': 'CNc1nc(-c2ccc3c(N)n[nH]c3c2)cc(N2C[C@@H](C(=O)NC3CCCCC3)CC[C@H]2C)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb2990>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.1,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb2f80>,
#   'Standard Value': 7943.0,
#   'std_smiles': 'CNc1nc(-c2ccc3c(N)n[nH]c3c2)cc(N2C[C@@H](C(=O)NC3CCCCC3)CC[C@H]2C)n1'},
#  {'smiles': 'Cc1n[nH]c(C)c1-c1cc2c(s1)C(=O)NC(C)(C)N2C',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb8030>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.68,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb8620>,
#   'Standard Value': 2100.0,
#   'std_smiles': 'Cc1n[nH]c(C)c1-c1cc2c(s1)C(=O)NC(C)(C)N2C'},
#  {'smiles': 'Nc1nc(-c2ccc3c(N)n[nH]c3c2)cc(N2CCC[C@H](C(=O)NC3CCCCC3)C2)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb2e40>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.3,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb2710>,
#   'Standard Value': 5011.87,
#   'std_smiles': 'Nc1nc(-c2ccc3c(N)n[nH]c3c2)cc(N2CCC[C@H](C(=O)NC3CCCCC3)C2)n1'},
#  {'smiles': 'CN(C1CC1)S(=O)(=O)c1ccc(-c2cnc(N)c(-c3ccc4c(c3)CCNC4=O)c2)c(F)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb24e0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 4.68,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faee90>,
#   'Standard Value': 20800.0,
#   'std_smiles': 'CN(C1CC1)S(=O)(=O)c1ccc(-c2cnc(N)c(-c3ccc4c(c3)CCNC4=O)c2)c(F)c1'},
#  {'smiles': 'CN1CCCN(c2nc(-c3ccncc3)cnc2N2CCCC2)CC1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fae940>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.22,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fae760>,
#   'Standard Value': 6000.0,
#   'std_smiles': 'CN1CCCN(c2nc(-c3ccncc3)cnc2N2CCCC2)CC1'},
#  {'smiles': 'CC1(C)C(=O)N([C@H]2CCc3c(O)cccc32)c2nc(Nc3ccccc3)ncc21',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faeb70>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fadc10>,
#   'Standard Value': 10000.0,
#   'std_smiles': 'CC1(C)C(=O)N([C@H]2CCc3c(O)cccc32)c2nc(Nc3ccccc3)ncc21'},
#  {'smiles': 'c1ccc(CNc2nc(Nc3ccncc3)nc(N3CCNCC3)n2)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fad5d0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.4,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fad7b0>,
#   'Standard Value': 400.0,
#   'std_smiles': 'c1ccc(CNc2nc(Nc3ccncc3)nc(N3CCNCC3)n2)cc1'},
#  {'smiles': 'c1ccc2c(c1)CC(Nc1nc(Nc3ccncc3)nc(N3CCCNCC3)n1)C2',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fad760>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.77,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fad080>,
#   'Standard Value': 17.0,
#   'std_smiles': 'c1ccc2c(c1)CC(Nc1nc(Nc3ccncc3)nc(N3CCCNCC3)n1)C2'},
#  {'smiles': 'CC[C@@H]1CO[C@H](C(=O)NC2CCCCC2)CN1c1cc(-c2ccc3c(N)n[nH]c3c2)nc(NC)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faaf30>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faa7b0>,
#   'Standard Value': 10000.0,
#   'std_smiles': 'CC[C@@H]1CO[C@H](C(=O)NC2CCCCC2)CN1c1cc(-c2ccc3c(N)n[nH]c3c2)nc(NC)n1'},
#  {'smiles': 'CC(C)(C)OC(=O)NC1CCCN(c2cc(-c3ccc4c(N)n[nH]c4c3)nc(N)n2)C1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faa4e0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa6d50>,
#   'Standard Value': 10000.0,
#   'std_smiles': 'CC(C)(C)OC(=O)NC1CCCN(c2cc(-c3ccc4c(N)n[nH]c4c3)nc(N)n2)C1'},
#  {'smiles': 'CCNc1cc(-c2ccc3c(N)[nH]nc3c2)nc(N)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa6b20>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa6760>,
#   'Standard Value': 10000.0,
#   'std_smiles': 'CCNc1cc(-c2ccc3c(N)[nH]nc3c2)nc(N)n1'},
#  {'smiles': 'Cn1cc(-c2cnc3c(-c4csc(C(=O)N[C@@H]5CCCC[C@@H]5N)c4)cnn3c2)cn1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa6580>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.77,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa5d00>,
#   'Standard Value': 17.0,
#   'std_smiles': 'Cn1cc(-c2cnc3c(-c4csc(C(=O)N[C@@H]5CCCC[C@@H]5N)c4)cnn3c2)cn1'},
#  {'smiles': 'COC[C@@H]1CCCN1C(=O)Cc1ccc(-c2n[nH]c(=O)c3ccccc23)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa5cb0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 4.79,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa58a0>,
#   'Standard Value': 16200.0,
#   'std_smiles': 'COC[C@@H]1CCCN1C(=O)Cc1ccc(-c2n[nH]c(=O)c3ccccc23)cc1'},
#  {'smiles': 'c1cc(Nc2nc(NC3CCCC3)nc(N3CCNCC3)n2)ccn1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa5710>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2080>,
#   'Standard Value': nan,
#   'std_smiles': 'c1cc(Nc2nc(NC3CCCC3)nc(N3CCNCC3)n2)ccn1'},
#  {'smiles': 'C[C@@H]1CN(c2nc(Nc3ccncc3)nc(NC3Cc4ccccc4C3)n2)CCN1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2030>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.1,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2cb0>,
#   'Standard Value': 8.0,
#   'std_smiles': 'C[C@@H]1CN(c2nc(Nc3ccncc3)nc(NC3Cc4ccccc4C3)n2)CCN1'},
#  {'smiles': 'C[C@@H](Nc1c(Nc2ccnc(-c3ccco3)c2)c(=O)c1=O)c1ccccc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2940>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f92300>,
#   'Standard Value': 50000.0,
#   'std_smiles': 'C[C@@H](Nc1c(Nc2ccnc(-c3ccco3)c2)c(=O)c1=O)c1ccccc1'},
#  {'smiles': 'Cc1c[nH]c2ncnc(N3CCN(/C(=N/C#N)Nc4ccc(F)c(Br)c4)[C@@H](C)C3)c12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f92530>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.51,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f92f80>,
#   'Standard Value': 310.0,
#   'std_smiles': 'Cc1c[nH]c2ncnc(N3CCN(/C(=N/C#N)Nc4ccc(F)c(Br)c4)[C@@H](C)C3)c12'},
#  {'smiles': 'c1ccc2c(c1)CC(Nc1nc(Nc3ccncc3)nc(N3CCNCC3)n1)C2',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f928f0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.22,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f978a0>,
#   'Standard Value': 6.0,
#   'std_smiles': 'c1ccc2c(c1)CC(Nc1nc(Nc3ccncc3)nc(N3CCNCC3)n1)C2'},
#  {'smiles': 'c1ccc(CCNc2nc(Nc3ccncc3)nc(N3CCNCC3)n2)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f97cb0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f96b70>,
#   'Standard Value': nan,
#   'std_smiles': 'c1ccc(CCNc2nc(Nc3ccncc3)nc(N3CCNCC3)n2)cc1'},
#  {'smiles': 'c1ccc(Nc2nc(NC3Cc4ccccc4C3)nc(N3CCNCC3)n2)nc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f968f0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f16d027bd00>,
#   'Standard Value': 1000.0,
#   'std_smiles': 'c1ccc(Nc2nc(NC3Cc4ccccc4C3)nc(N3CCNCC3)n2)nc1'},
#  {'smiles': 'c1ccc2c(c1)CC(Nc1cc(N3CCNCC3)nc(Nc3ccncc3)n1)C2',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f9f990>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.85,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f96bc0>,
#   'Standard Value': 14.0,
#   'std_smiles': 'c1ccc2c(c1)CC(Nc1cc(N3CCNCC3)nc(Nc3ccncc3)n1)C2'},
#  {'smiles': 'c1ccc2c(c1)CC(Nc1nc(Nc3ccncc3)cc(N3CCNCC3)n1)C2',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb8940>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f9fc60>,
#   'Standard Value': nan,
#   'std_smiles': 'c1ccc2c(c1)CC(Nc1nc(Nc3ccncc3)cc(N3CCNCC3)n1)C2'},
#  {'smiles': 'C[C@@H](N)[C@H]1CC[C@H](C(=O)Nc2ccncc2)CC1.Cl.Cl',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb8e40>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.34,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fba3a0>,
#   'Standard Value': 46.0,
#   'std_smiles': 'C[C@@H](N)[C@H]1CC[C@H](C(=O)Nc2ccncc2)CC1'},
#  {'smiles': 'Cc1c(-c2ccnc(N(C)C)n2)sc2ccc(Cl)cc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb8990>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb8e90>,
#   'Standard Value': 100000.0,
#   'std_smiles': 'Cc1c(-c2ccnc(N(C)C)n2)sc2ccc(Cl)cc12'},
#  {'smiles': 'Cc1c(-c2ccnc(N)n2)sc2ccc(Cc3cccc(O)c3)cc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fba8a0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.7,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fba3f0>,
#   'Standard Value': 20.0,
#   'std_smiles': 'Cc1c(-c2ccnc(N)n2)sc2ccc(Cc3cccc(O)c3)cc12'},
#  {'smiles': 'O=S(=O)(c1cccc2cnccc12)N1CCCNCC1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbada0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.37,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fba8f0>,
#   'Standard Value': 4300.0,
#   'std_smiles': 'O=S(=O)(c1cccc2cnccc12)N1CCCNCC1'},
#  {'smiles': 'CN(C)C(C(=O)Nc1cc2cc[nH]c(=O)c2cc1Cl)c1ccccc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbd300>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.72,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbadf0>,
#   'Standard Value': 19.0,
#   'std_smiles': 'CN(C)C(C(=O)Nc1cc2cc[nH]c(=O)c2cc1Cl)c1ccccc1'},
#  {'smiles': 'CCn1c(-c2nonc2N)nc2cnc(Oc3cccc(NC(=O)c4ccccc4)c3)cc21',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbd800>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.4,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbd350>,
#   'Standard Value': 4.0,
#   'std_smiles': 'CCn1c(-c2nonc2N)nc2cnc(Oc3cccc(NC(=O)c4ccccc4)c3)cc21'},
#  {'smiles': 'O=C(Nc1ccc(-c2cn[nH]c2)cc1)NC(CCO)c1cccc(F)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbdd00>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbd850>,
#   'Standard Value': 10.0,
#   'std_smiles': 'O=C(Nc1ccc(-c2cn[nH]c2)cc1)NC(CCO)c1cccc(F)c1'},
#  {'smiles': 'Cc1n[nH]c2ccc(-c3cc(OC[C@@H](N)Cc4ccccc4)cnc3-c3ccoc3)cc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc0350>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.28,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbdd50>,
#   'Standard Value': 5200.0,
#   'std_smiles': 'Cc1n[nH]c2ccc(-c3cc(OC[C@@H](N)Cc4ccccc4)cnc3-c3ccoc3)cc12'},
#  {'smiles': 'Cc1n[nH]c2ccc(-c3cc(OC[C@@H](N)Cc4ccccc4)cnc3-c3cc(F)ccc3O)cc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc0940>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.01,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc03a0>,
#   'Standard Value': 9800.0,
#   'std_smiles': 'Cc1n[nH]c2ccc(-c3cc(OC[C@@H](N)Cc4ccccc4)cnc3-c3cc(F)ccc3O)cc12'},
#  {'smiles': 'Nc1nc(-c2ccccc2)cc(-c2ccc3c(N)n[nH]c3c2)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc0f30>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc0990>,
#   'Standard Value': 10000.0,
#   'std_smiles': 'Nc1nc(-c2ccccc2)cc(-c2ccc3c(N)n[nH]c3c2)n1'},
#  {'smiles': 'C[C@@H](N)[C@H]1CC[C@H](C(=O)Nc2ccnc3[nH]ccc23)CC1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc1580>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.52,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc0f80>,
#   'Standard Value': 30.0,
#   'std_smiles': 'C[C@@H](N)[C@H]1CC[C@H](C(=O)Nc2ccnc3[nH]ccc23)CC1'},
#  {'smiles': 'CC1=C(C(=O)Nc2ccc3[nH]ncc3c2)C(c2ccc(F)cc2)N=C(c2ccccc2)N1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc0b70>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.98,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc0a80>,
#   'Standard Value': 105.0,
#   'std_smiles': 'CC1=C(C(=O)Nc2ccc3[nH]ncc3c2)C(c2ccc(F)cc2)N=C(c2ccccc2)N1'},
#  {'smiles': 'c1cc(-c2ncc(-c3ccc(-c4cnco4)cn3)o2)nc(-c2ncc(-c3ccc(-c4cnco4)cn3)o2)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc0800>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc0620>,
#   'Standard Value': 1000.0,
#   'std_smiles': 'c1cc(-c2ncc(-c3ccc(-c4cnco4)cn3)o2)nc(-c2ncc(-c3ccc(-c4cnco4)cn3)o2)c1'},
#  {'smiles': 'CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC3CCNCC3)c21.O=C(O)C(F)(F)F',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc0120>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbd0d0>,
#   'Standard Value': 1000.0,
#   'std_smiles': 'CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OC3CCNCC3)c21'},
#  {'smiles': 'COc1ccc(C2=NC(c3ccc(C(F)(F)F)cc3F)C(C(=O)Nc3ccc4[nH]ncc4c3)=C(C)N2)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc07b0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.58,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc0260>,
#   'Standard Value': 26.0,
#   'std_smiles': 'COc1ccc(C2=NC(c3ccc(C(F)(F)F)cc3F)C(C(=O)Nc3ccc4[nH]ncc4c3)=C(C)N2)cc1'},
#  {'smiles': 'CC1=C(C(=O)Nc2ccc3[nH]ncc3c2)C(c2ccc(F)cc2)NC(=O)N1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbd710>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.85,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbde40>,
#   'Standard Value': 14.0,
#   'std_smiles': 'CC1=C(C(=O)Nc2ccc3[nH]ncc3c2)C(c2ccc(F)cc2)NC(=O)N1'},
#  {'smiles': 'CCn1cc(-c2ccnc3[nH]ccc23)c(-c2ccc(NC(=O)Nc3ccccc3)cc2)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbd2b0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.4,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbd6c0>,
#   'Standard Value': 398.0,
#   'std_smiles': 'CCn1cc(-c2ccnc3[nH]ccc23)c(-c2ccc(NC(=O)Nc3ccccc3)cc2)n1'},
#  {'smiles': 'NCCNc1nc(-c2ccncc2)cc2cnccc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbaee0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.52,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbd120>,
#   'Standard Value': 30.0,
#   'std_smiles': 'NCCNc1nc(-c2ccncc2)cc2cnccc12'},
#  {'smiles': 'CC(C)(N)CNc1nc(-c2ccncc2)nc2cnccc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fba710>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.92,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbad00>,
#   'Standard Value': 12.0,
#   'std_smiles': 'CC(C)(N)CNc1nc(-c2ccncc2)nc2cnccc12'},
#  {'smiles': 'O=C(NCc1ccco1)Nc1nc(-c2ccncc2)cs1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fba1c0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.93,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fba530>,
#   'Standard Value': 1170.0,
#   'std_smiles': 'O=C(NCc1ccco1)Nc1nc(-c2ccncc2)cs1'},
#  {'smiles': 'C[C@H](NC(=O)Nc1nc(-c2ccncc2)cs1)c1cccc(Cl)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb8c60>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb8bc0>,
#   'Standard Value': 50000.0,
#   'std_smiles': 'C[C@H](NC(=O)Nc1nc(-c2ccncc2)cs1)c1cccc(Cl)c1'},
#  {'smiles': 'C[C@@H](NC(=O)Nc1nc(-c2ccncc2)cs1)c1cccc(Cl)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f9f350>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.26,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb8a80>,
#   'Standard Value': 550.0,
#   'std_smiles': 'C[C@@H](NC(=O)Nc1nc(-c2ccncc2)cs1)c1cccc(Cl)c1'},
#  {'smiles': 'O=C(Nc1nc(-c2ccncc2)cs1)NC1Cc2ccccc2C1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f96030>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 4.39,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f9f2b0>,
#   'Standard Value': 40910.0,
#   'std_smiles': 'O=C(Nc1nc(-c2ccncc2)cs1)NC1Cc2ccccc2C1'},
#  {'smiles': 'CC(NC(=O)Nc1nc(-c2ccncc2)cs1)c1cccc(F)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f97850>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.37,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f96940>,
#   'Standard Value': 430.0,
#   'std_smiles': 'CC(NC(=O)Nc1nc(-c2ccncc2)cs1)c1cccc(F)c1'},
#  {'smiles': 'C=CC(NC(=O)c1ccc(-c2cn[nH]c2)c(OC)c1)c1c(F)cccc1F',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f910d0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.76,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f97350>,
#   'Standard Value': 17.5,
#   'std_smiles': 'C=CC(NC(=O)c1ccc(-c2cn[nH]c2)c(OC)c1)c1c(F)cccc1F'},
#  {'smiles': 'COc1cc(C(=O)N[C@@H](CO)c2c(F)cccc2F)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2530>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.62,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f91cb0>,
#   'Standard Value': 23.8,
#   'std_smiles': 'COc1cc(C(=O)N[C@@H](CO)c2c(F)cccc2F)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cc(C(=O)NC(c2ccccc2F)C(C)(C)O)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa5170>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.79,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2350>,
#   'Standard Value': 16.2,
#   'std_smiles': 'COc1cc(C(=O)NC(c2ccccc2F)C(C)(C)O)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cc(-c2c[nH]nc2C(F)(F)F)ccc1C(=O)NCc1c(F)cccc1Cl',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa5f80>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.41,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa5260>,
#   'Standard Value': 39.4,
#   'std_smiles': 'COc1cc(-c2c[nH]nc2C(F)(F)F)ccc1C(=O)NCc1c(F)cccc1Cl'},
#  {'smiles': 'CCOc1cc(C(=O)N[C@H](CO)c2ccccc2)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa68a0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.29,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa5d50>,
#   'Standard Value': 50.8,
#   'std_smiles': 'CCOc1cc(C(=O)N[C@H](CO)c2ccccc2)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cc(-c2cn[nH]c2)ccc1C(=O)N[C@H](CO)c1c(F)cccc1F',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faa800>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.44,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa6d00>,
#   'Standard Value': 362.0,
#   'std_smiles': 'COc1cc(-c2cn[nH]c2)ccc1C(=O)N[C@H](CO)c1c(F)cccc1F'},
#  {'smiles': 'COc1cc(C(=O)NC(C)c2cccc(CN3CCN(C)CC3)c2)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fadad0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.81,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faaa30>,
#   'Standard Value': 156.0,
#   'std_smiles': 'COc1cc(C(=O)NC(C)c2cccc(CN3CCN(C)CC3)c2)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cc(C(=O)NCc2cccc(N3CCCC3)c2)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fae3f0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.14,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fadd00>,
#   'Standard Value': 724.0,
#   'std_smiles': 'COc1cc(C(=O)NCc2cccc(N3CCCC3)c2)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cc(C(=O)NCc2cccc(N(C)C)c2)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb21c0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.43,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fae490>,
#   'Standard Value': 371.0,
#   'std_smiles': 'COc1cc(C(=O)NCc2cccc(N(C)C)c2)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cc(C(=O)NCc2ccc(Cl)cc2F)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc13a0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.8,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb26c0>,
#   'Standard Value': 15.8,
#   'std_smiles': 'COc1cc(C(=O)NCc2ccc(Cl)cc2F)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cc(C(=O)NCCc2cccc(O)c2)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc1df0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.67,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc1350>,
#   'Standard Value': 21.5,
#   'std_smiles': 'COc1cc(C(=O)NCCc2cccc(O)c2)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cccc(C(C)NC(=O)c2ccc(-c3cn[nH]c3)c(OC)c2)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc4350>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.13,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc1e40>,
#   'Standard Value': 73.4,
#   'std_smiles': 'COc1cccc(C(C)NC(=O)c2ccc(-c3cn[nH]c3)c(OC)c2)n1'},
#  {'smiles': 'COc1ccc(F)c(C(C)NC(=O)c2ccc(-c3cn[nH]c3)c(OC)c2)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc4850>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.76,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc43a0>,
#   'Standard Value': 172.0,
#   'std_smiles': 'COc1ccc(F)c(C(C)NC(=O)c2ccc(-c3cn[nH]c3)c(OC)c2)c1'},
#  {'smiles': 'CCn1c(-c2nonc2N)nc2cnc(Oc3cccc(S(C)(=O)=O)c3)cc21',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc4d50>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.48,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc48a0>,
#   'Standard Value': 33.0,
#   'std_smiles': 'CCn1c(-c2nonc2N)nc2cnc(Oc3cccc(S(C)(=O)=O)c3)cc21'},
#  {'smiles': 'Cc1n[nH]cc1-c1cc2nc(C3CCCCC3)[nH]c(=O)c2s1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f462b0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.03,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc4da0>,
#   'Standard Value': 940.0,
#   'std_smiles': 'Cc1n[nH]cc1-c1cc2nc(C3CCCCC3)[nH]c(=O)c2s1'},
#  {'smiles': 'COc1cccc([C@@H](C)NC(=O)c2ccc(-c3ccnc(NCC(C)(C)O)c3)cc2)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f467b0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.62,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f46300>,
#   'Standard Value': 2400.0,
#   'std_smiles': 'COc1cccc([C@@H](C)NC(=O)c2ccc(-c3ccnc(NCC(C)(C)O)c3)cc2)c1'},
#  {'smiles': 'CCCOc1cccc([C@@H](CCO)NC(=O)c2ccc(-c3ccnc(F)c3)cc2)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f46cb0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.8,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f46800>,
#   'Standard Value': 1600.0,
#   'std_smiles': 'CCCOc1cccc([C@@H](CCO)NC(=O)c2ccc(-c3ccnc(F)c3)cc2)c1'},
#  {'smiles': 'COc1ccccc1CNC(=O)Nc1nc(-c2ccncc2)cs1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4a260>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.85,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f46d00>,
#   'Standard Value': 1400.0,
#   'std_smiles': 'COc1ccccc1CNC(=O)Nc1nc(-c2ccncc2)cs1'},
#  {'smiles': 'O=C(NCc1ccc(Cl)cc1)Nc1nc(-c2ccncc2)cs1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4a850>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.62,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4a2b0>,
#   'Standard Value': 2400.0,
#   'std_smiles': 'O=C(NCc1ccc(Cl)cc1)Nc1nc(-c2ccncc2)cs1'},
#  {'smiles': 'COc1cccc(CNC(=O)N(C)c2nc(-c3ccncc3)cs2)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4ae40>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.52,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4a8a0>,
#   'Standard Value': 30.0,
#   'std_smiles': 'COc1cccc(CNC(=O)N(C)c2nc(-c3ccncc3)cs2)c1'},
#  {'smiles': 'Cc1c(C(=O)N2CCOc3ccc(-c4ccc(N)nc4)cc3C2)ccc(S(C)(=O)=O)c1F',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4a940>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4ae90>,
#   'Standard Value': 10000.0,
#   'std_smiles': 'Cc1c(C(=O)N2CCOc3ccc(-c4ccc(N)nc4)cc3C2)ccc(S(C)(=O)=O)c1F'},
#  {'smiles': 'OCCN1CCN(c2nc(-c3ccncc3)cnc2N2CCCC2)CC1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4a3a0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.24,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4ad50>,
#   'Standard Value': 570.0,
#   'std_smiles': 'OCCN1CCN(c2nc(-c3ccncc3)cnc2N2CCCC2)CC1'},
#  {'smiles': 'CN(C)c1nc([C@@H]2CNC[C@H]2c2ccccc2)nc2ccc(-c3cn[nH]c3)cc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f46a80>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4a170>,
#   'Standard Value': nan,
#   'std_smiles': 'CN(C)c1nc([C@@H]2CNC[C@H]2c2ccccc2)nc2ccc(-c3cn[nH]c3)cc12'},
#  {'smiles': 'CC1=C(C(=O)Nc2ccc3[nH]ncc3c2)C(c2ccc(F)c(C(=O)NCCc3c(C)cccc3C)c2)NC(=O)N1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f46940>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.54,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f46990>,
#   'Standard Value': 290.0,
#   'std_smiles': 'CC1=C(C(=O)Nc2ccc3[nH]ncc3c2)C(c2ccc(F)c(C(=O)NCCc3c(C)cccc3C)c2)NC(=O)N1'},
#  {'smiles': 'COc1cccc(OC)c1CNC(=O)Cc1cc(C2NC(=O)NC(C)=C2C(=O)Nc2ccc3[nH]ncc3c2)ccc1F',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f465d0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.7,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f468a0>,
#   'Standard Value': 200.0,
#   'std_smiles': 'COc1cccc(OC)c1CNC(=O)Cc1cc(C2NC(=O)NC(C)=C2C(=O)Nc2ccc3[nH]ncc3c2)ccc1F'},
#  {'smiles': 'COc1cccc(CN(CCN2CCCCC2)C(=O)Nc2ccc(-c3cn[nH]c3)cc2)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc4b20>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.85,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f463f0>,
#   'Standard Value': 14.0,
#   'std_smiles': 'COc1cccc(CN(CCN2CCCCC2)C(=O)Nc2ccc(-c3cn[nH]c3)cc2)c1'},
#  {'smiles': 'C[C@H](c1ccccc1)N1c2cc(-n3c(=O)[nH]c4ncccc43)ccc2C(=O)NC1(C)C',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc49e0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc4a30>,
#   'Standard Value': 1000.0,
#   'std_smiles': 'C[C@H](c1ccccc1)N1c2cc(-n3c(=O)[nH]c4ncccc43)ccc2C(=O)NC1(C)C'},
#  {'smiles': 'Cc1ncc(C#N)c(Nc2ccc3[nH]ccc3c2C)c1/C=C/c1cccc(S(=O)(=O)N2CCN(C)CC2)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc4800>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc4940>,
#   'Standard Value': 50000.0,
#   'std_smiles': 'Cc1ncc(C#N)c(Nc2ccc3[nH]ccc3c2C)c1/C=C/c1cccc(S(=O)(=O)N2CCN(C)CC2)c1'},
#  {'smiles': 'Cc1c(Nc2c(C#N)cncc2-c2cc3cc(CN4CCN(C)CC4)ccc3o2)ccc2[nH]ccc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc1f30>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc4670>,
#   'Standard Value': 9000.0,
#   'std_smiles': 'Cc1c(Nc2c(C#N)cncc2-c2cc3cc(CN4CCN(C)CC4)ccc3o2)ccc2[nH]ccc12'},
#  {'smiles': 'COc1ccc([C@@H]2CN(C)C[C@H]2c2nc3ccc(-c4cn[nH]c4)cc3c(=O)[nH]2)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc13f0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.89,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc1d50>,
#   'Standard Value': 13.0,
#   'std_smiles': 'COc1ccc([C@@H]2CN(C)C[C@H]2c2nc3ccc(-c4cn[nH]c4)cc3c(=O)[nH]2)cc1'},
#  {'smiles': 'CCOc1cc(C2=NC(c3ccc(Cl)cc3F)C(C(=O)Nc3cc4cn[nH]c4cc3F)=C(C)N2)ccn1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fae800>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.96,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb2a80>,
#   'Standard Value': 11.0,
#   'std_smiles': 'CCOc1cc(C2=NC(c3ccc(Cl)cc3F)C(C(=O)Nc3cc4cn[nH]c4cc3F)=C(C)N2)ccn1'},
#  {'smiles': 'CCn1c(-c2nonc2N)nc2c(-c3cn[nH]c3)ncc(OCCCN)c21',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faddf0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.65,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faef80>,
#   'Standard Value': 224.0,
#   'std_smiles': 'CCn1c(-c2nonc2N)nc2c(-c3cn[nH]c3)ncc(OCCCN)c21'},
#  {'smiles': 'CN(C)CC(=O)NC(c1ccc(Cl)cc1)c1nc2ccc(-c3cn[nH]c3)cc2c(=O)[nH]1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faab70>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fada80>,
#   'Standard Value': 1.0,
#   'std_smiles': 'CN(C)CC(=O)NC(c1ccc(Cl)cc1)c1nc2ccc(-c3cn[nH]c3)cc2c(=O)[nH]1'},
#  {'smiles': 'c1cc2[nH]ncc2cc1-c1cncc(N2CCCNCC2)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa6260>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.98,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691faa1c0>,
#   'Standard Value': 105.0,
#   'std_smiles': 'c1cc2[nH]ncc2cc1-c1cncc(N2CCCNCC2)n1'},
#  {'smiles': 'c1ccc2c(c1)CCC(Nc1nc(Nc3ccncc3)nc(N3CCNCC3)n1)C2',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa5da0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa62b0>,
#   'Standard Value': nan,
#   'std_smiles': 'c1ccc2c(c1)CCC(Nc1nc(Nc3ccncc3)nc(N3CCNCC3)n1)C2'},
#  {'smiles': 'c1ccc2c(c1)CC(Nc1nc(Nc3ccncc3)nc(N3CCCCC3)n1)C2',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa2d00>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa5a80>,
#   'Standard Value': nan,
#   'std_smiles': 'c1ccc2c(c1)CC(Nc1nc(Nc3ccncc3)nc(N3CCCCC3)n1)C2'},
#  {'smiles': 'CN1CCN(c2nc(Nc3ccncc3)nc(NC3Cc4ccccc4C3)n2)CC1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f92c60>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.52,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fa28f0>,
#   'Standard Value': 305.0,
#   'std_smiles': 'CN1CCN(c2nc(Nc3ccncc3)nc(NC3Cc4ccccc4C3)n2)CC1'},
#  {'smiles': 'CNCCN(C)c1nc(Nc2ccncc2)nc(NC2Cc3ccccc3C2)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f978f0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.09,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f92580>,
#   'Standard Value': 81.0,
#   'std_smiles': 'CNCCN(C)c1nc(Nc2ccncc2)nc(NC2Cc3ccccc3C2)n1'},
#  {'smiles': 'CC1=C(C(=O)Nc2ccc3[nH]ncc3c2)C(c2ccc(F)cc2)N=C(c2ccncc2)N1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb87b0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.1,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f97c10>,
#   'Standard Value': 8.0,
#   'std_smiles': 'CC1=C(C(=O)Nc2ccc3[nH]ncc3c2)C(c2ccc(F)cc2)N=C(c2ccncc2)N1'},
#  {'smiles': 'CC1=C(C(=O)Nc2ccc3[nH]ncc3c2)C(c2ccc(Cl)cc2F)N=C(c2ccnc(Cl)c2)N1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fba2b0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.4,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fb8850>,
#   'Standard Value': 4.0,
#   'std_smiles': 'CC1=C(C(=O)Nc2ccc3[nH]ncc3c2)C(c2ccc(Cl)cc2F)N=C(c2ccnc(Cl)c2)N1'},
#  {'smiles': 'CN1C[C@@H]2C[C@H]1CN2c1ccc(-c2ccnc3c(-c4cccc(O)c4)c(-c4ccncc4)nn23)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbaf30>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 4.75,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fba4e0>,
#   'Standard Value': 17600.0,
#   'std_smiles': 'CN1C[C@@H]2C[C@H]1CN2c1ccc(-c2ccnc3c(-c4cccc(O)c4)c(-c4ccncc4)nn23)cc1'},
#  {'smiles': 'COc1cc2c(cc1Cl)C(c1ccc(Cl)c(Cl)c1)=NCC2',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbd3f0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fba670>,
#   'Standard Value': 10000.0,
#   'std_smiles': 'COc1cc2c(cc1Cl)C(c1ccc(Cl)c(Cl)c1)=NCC2'},
#  {'smiles': 'COc1ccc(C2=NC(c3ccc(Cl)cc3F)C(C(=O)Nc3ccc4[nH]ncc4c3)=C(C)N2)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbd4e0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.3,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbd940>,
#   'Standard Value': 5.0,
#   'std_smiles': 'COc1ccc(C2=NC(c3ccc(Cl)cc3F)C(C(=O)Nc3ccc4[nH]ncc4c3)=C(C)N2)cc1'},
#  {'smiles': 'Cc1c[nH]c2ncnc(N3CCN(/C(=N/C#N)Nc4cccc(Br)c4)[C@@H](C)C3)c12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc0da0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.58,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbdad0>,
#   'Standard Value': 260.0,
#   'std_smiles': 'Cc1c[nH]c2ncnc(N3CCN(/C(=N/C#N)Nc4cccc(Br)c4)[C@@H](C)C3)c12'},
#  {'smiles': 'C[C@@H]1CO[C@H](C(=O)Nc2ccccc2)CN1c1cc(-c2ccc3c(N)n[nH]c3c2)nc(N)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4b3a0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.8,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc0030>,
#   'Standard Value': 158.49,
#   'std_smiles': 'C[C@@H]1CO[C@H](C(=O)Nc2ccccc2)CN1c1cc(-c2ccc3c(N)n[nH]c3c2)nc(N)n1'},
#  {'smiles': 'Nc1nc(-c2ccc3c(N)n[nH]c3c2)cc(N2CCC[C@H](C(=O)NC3CCCC3)C2)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4b8a0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4b3f0>,
#   'Standard Value': 10000.0,
#   'std_smiles': 'Nc1nc(-c2ccc3c(N)n[nH]c3c2)cc(N2CCC[C@H](C(=O)NC3CCCC3)C2)n1'},
#  {'smiles': 'CNc1nc(-c2ccc3c(N)n[nH]c3c2)cc(N2C[C@H](C)C[C@@H](N(C)C(=O)OC(C)(C)C)C2)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4bda0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4b8f0>,
#   'Standard Value': 10000.0,
#   'std_smiles': 'CNc1nc(-c2ccc3c(N)n[nH]c3c2)cc(N2C[C@H](C)C[C@@H](N(C)C(=O)OC(C)(C)C)C2)n1'},
#  {'smiles': 'Cc1c(Nc2c(C#N)cncc2/C=C/c2cccc(S(=O)(=O)N3CCN(C)CC3)c2)ccc2[nH]ccc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4d300>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4bdf0>,
#   'Standard Value': 50000.0,
#   'std_smiles': 'Cc1c(Nc2c(C#N)cncc2/C=C/c2cccc(S(=O)(=O)N3CCN(C)CC3)c2)ccc2[nH]ccc12'},
#  {'smiles': 'CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OCCCNCCc3ccc(OC)cc3)c21',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4d800>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.4,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4d350>,
#   'Standard Value': 3980.0,
#   'std_smiles': 'CCn1c(-c2nonc2N)nc2c(C#CC(C)(C)O)ncc(OCCCNCCc3ccc(OC)cc3)c21'},
#  {'smiles': 'O=c1[nH]ccc2cc(O[C@H]3CCCNC3)ccc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4dd00>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.21,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4d850>,
#   'Standard Value': 61.66,
#   'std_smiles': 'O=c1[nH]ccc2cc(O[C@H]3CCCNC3)ccc12'},
#  {'smiles': 'c1ccc(CN2CCC[C@H](Oc3ccc4cnccc4c3)C2)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f53260>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.77,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4dd50>,
#   'Standard Value': 169.82,
#   'std_smiles': 'c1ccc(CN2CCC[C@H](Oc3ccc4cnccc4c3)C2)cc1'},
#  {'smiles': 'c1cc2cc(OC3CCCNC3)ccc2cn1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f53760>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.75,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f532b0>,
#   'Standard Value': 1778.28,
#   'std_smiles': 'c1cc2cc(OC3CCCNC3)ccc2cn1'},
#  {'smiles': 'Cc1c(-c2ccnc3[nH]ccc23)sc2ccc(Cl)cc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f53da0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.15,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4de90>,
#   'Standard Value': 7100.0,
#   'std_smiles': 'Cc1c(-c2ccnc3[nH]ccc23)sc2ccc(Cl)cc12'},
#  {'smiles': 'COc1ccc(C(N)c2ccc3sc(-c4ccnc(N)n4)c(C)c3c2)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4ddf0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.05,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4d940>,
#   'Standard Value': 90.0,
#   'std_smiles': 'COc1ccc(C(N)c2ccc3sc(-c4ccnc(N)n4)c(C)c3c2)cc1'},
#  {'smiles': 'COc1cccc(CNC(=O)c2cc3ccc(-c4cn[nH]c4)nc3[nH]2)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4d760>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.92,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4d4e0>,
#   'Standard Value': 12.0,
#   'std_smiles': 'COc1cccc(CNC(=O)c2cc3ccc(-c4cn[nH]c4)nc3[nH]2)c1'},
#  {'smiles': 'Nc1nc(NC2CCCC2)cc(-c2ccc3c(N)n[nH]c3c2)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4d170>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.2,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4d710>,
#   'Standard Value': 6309.57,
#   'std_smiles': 'Nc1nc(NC2CCCC2)cc(-c2ccc3c(N)n[nH]c3c2)n1'},
#  {'smiles': 'Cc1n[nH]c2ccc(-c3cc(OC[C@@H](N)Cc4ccccc4)cnc3-c3ccco3)cc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4b580>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.89,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4d2b0>,
#   'Standard Value': 1290.0,
#   'std_smiles': 'Cc1n[nH]c2ccc(-c3cc(OC[C@@H](N)Cc4ccccc4)cnc3-c3ccco3)cc12'},
#  {'smiles': 'Cc1n[nH]cc1-c1cc2nc([C@]3(C)CCCN3)[nH]c(=O)c2s1.Cl.Cl',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4b9e0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.57,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4b260>,
#   'Standard Value': 270.0,
#   'std_smiles': 'Cc1n[nH]cc1-c1cc2nc([C@]3(C)CCCN3)[nH]c(=O)c2s1'},
#  {'smiles': 'O=C(NCc1ccc(F)cc1)Nc1nc(-c2ccncc2)cs1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4bee0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.24,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4b800>,
#   'Standard Value': 570.0,
#   'std_smiles': 'O=C(NCc1ccc(F)cc1)Nc1nc(-c2ccncc2)cs1'},
#  {'smiles': 'O=C(Nc1nc(-c2ccncc2)cs1)N1CCN(CC2CCCO2)CC1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc0e40>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.68,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f4b210>,
#   'Standard Value': 210.0,
#   'std_smiles': 'O=C(Nc1nc(-c2ccncc2)cs1)N1CCN(CC2CCCO2)CC1'},
#  {'smiles': 'O=C(Nc1ccccc1)Nc1nc(-c2ccncc2)cs1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fbde90>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 4.98,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fc04e0>,
#   'Standard Value': 10430.0,
#   'std_smiles': 'O=C(Nc1ccccc1)Nc1nc(-c2ccncc2)cs1'},
# ...
#   'Standard Value': 10000.0,
#   'std_smiles': 'CN1CCN(c2nc(C3=C(c4c[nH]c5ccccc45)C(=O)NC3=O)c3ccccc3n2)CC1'},
#  {'smiles': 'Cc1[nH]c2ncnc(-c3ccc(NC(=O)Nc4cccc(C(=O)NC(C)C)c4)cc3)c2c1C',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f25cb0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f2c580>,
#   'Standard Value': 20000.0,
#   'std_smiles': 'Cc1[nH]c2ncnc(-c3ccc(NC(=O)Nc4cccc(C(=O)NC(C)C)c4)cc3)c2c1C'},
#  {'smiles': 'Cc1c[nH]c2ncnc(-c3ccc(NC(=O)N(CCO)c4ccccc4)cc3)c12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f357b0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.26,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f25c10>,
#   'Standard Value': 5536.0,
#   'std_smiles': 'Cc1c[nH]c2ncnc(-c3ccc(NC(=O)N(CCO)c4ccccc4)cc3)c12'},
#  {'smiles': 'Cc1c[nH]c2ncnc(-c3ccc(NC(=O)N(CCO)c4ccc(Cl)cc4)cc3)c12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f38210>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.23,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f38850>,
#   'Standard Value': 5915.0,
#   'std_smiles': 'Cc1c[nH]c2ncnc(-c3ccc(NC(=O)N(CCO)c4ccc(Cl)cc4)cc3)c12'},
#  {'smiles': 'Cc1[nH]c2ncnc(-c3ccc(NC(=O)N(CCN)c4ccc(Cl)cc4)c(F)c3)c2c1C',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f2dda0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f385d0>,
#   'Standard Value': nan,
#   'std_smiles': 'Cc1[nH]c2ncnc(-c3ccc(NC(=O)N(CCN)c4ccc(Cl)cc4)c(F)c3)c2c1C'},
#  {'smiles': 'COc1cccc(CNC(=O)c2cc3ccc(-c4ccnc(N)n4)cc3[nH]2)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f7bda0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.32,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f164e0>,
#   'Standard Value': 480.0,
#   'std_smiles': 'COc1cccc(CNC(=O)c2cc3ccc(-c4ccnc(N)n4)cc3[nH]2)c1'},
#  {'smiles': 'COc1cccc(CNC(=O)c2cc3cnc(-c4ccncc4)cc3[nH]2)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f598f0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.96,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f7b300>,
#   'Standard Value': 1100.0,
#   'std_smiles': 'COc1cccc(CNC(=O)c2cc3cnc(-c4ccncc4)cc3[nH]2)c1'},
#  {'smiles': 'COc1cccc(CNC(=O)c2c[nH]c3nc(-c4cn[nH]c4)ccc23)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fba490>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.96,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f57580>,
#   'Standard Value': 11.0,
#   'std_smiles': 'COc1cccc(CNC(=O)c2c[nH]c3nc(-c4cn[nH]c4)ccc23)c1'},
#  {'smiles': 'COc1ccc(CNC(=O)c2c[nH]c3cc(-c4cn[nH]c4)ccc23)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1692565c10>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.72,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f46d50>,
#   'Standard Value': 1900.0,
#   'std_smiles': 'COc1ccc(CNC(=O)c2c[nH]c3cc(-c4cn[nH]c4)ccc23)cc1'},
#  {'smiles': 'COc1cccc([C@@H](C)NC(=O)c2c[nH]c3cc(-c4cn[nH]c4)ccc23)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f169255c580>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.7,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f16925653a0>,
#   'Standard Value': 2.0,
#   'std_smiles': 'COc1cccc([C@@H](C)NC(=O)c2c[nH]c3cc(-c4cn[nH]c4)ccc23)c1'},
#  {'smiles': 'O=c1ncn2nc(Sc3ccc(F)cc3F)ccc2c1-c1c(Cl)cccc1Cl',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f37b70>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f169255ca80>,
#   'Standard Value': 5000.0,
#   'std_smiles': 'O=c1ncn2nc(Sc3ccc(F)cc3F)ccc2c1-c1c(Cl)cccc1Cl'},
#  {'smiles': 'Cc1n[nH]cc1-c1cc2c(s1)C(=O)N[C@]1(CC[C@](O)(c3ccc(F)cc3)CC1)N2',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f21a30>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.09,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f37670>,
#   'Standard Value': 820.0,
#   'std_smiles': 'Cc1n[nH]cc1-c1cc2c(s1)C(=O)N[C@]1(CC[C@](O)(c3ccc(F)cc3)CC1)N2'},
#  {'smiles': 'CN1C(=O)c2sc(-c3ccncc3)cc2NC1(C)C',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f32260>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.62,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f214e0>,
#   'Standard Value': 240.0,
#   'std_smiles': 'CN1C(=O)c2sc(-c3ccncc3)cc2NC1(C)C'},
#  {'smiles': 'Cl.Cn1nccc1-c1ccc(C(=O)N[C@@H]2CNCC[C@H]2c2ccc(F)c(F)c2)c(F)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f0c580>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.45,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f697b0>,
#   'Standard Value': 354.0,
#   'std_smiles': 'Cn1nccc1-c1ccc(C(=O)N[C@@H]2CNCC[C@H]2c2ccc(F)c(F)c2)c(F)c1'},
#  {'smiles': 'O=C(Nc1nc(-c2ccncc2)cs1)Nc1ccccc1Cl',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f327b0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.6,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f0cd50>,
#   'Standard Value': 2490.0,
#   'std_smiles': 'O=C(Nc1nc(-c2ccncc2)cs1)Nc1ccccc1Cl'},
#  {'smiles': 'COc1ccc(CNC(=O)Nc2nc(-c3ccncc3)cs2)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fad8f0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.04,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f69a80>,
#   'Standard Value': 9120.0,
#   'std_smiles': 'COc1ccc(CNC(=O)Nc2nc(-c3ccncc3)cs2)cc1'},
#  {'smiles': 'CN(C)c1ccc(C(=O)Nc2ccc(CNC(=O)COc3ccc4c(=O)ccoc4c3)cc2)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f6e710>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691fad490>,
#   'Standard Value': 10000.0,
#   'std_smiles': 'CN(C)c1ccc(C(=O)Nc2ccc(CNC(=O)COc3ccc4c(=O)ccoc4c3)cc2)cc1'},
#  {'smiles': 'COc1cccc([C@@H](C)NC(=O)c2ccc3c(c2)OC(C)c2cnccc2-3)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f1cbc0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.82,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f6e260>,
#   'Standard Value': 15.0,
#   'std_smiles': 'COc1cccc([C@@H](C)NC(=O)c2ccc3c(c2)OC(C)c2cnccc2-3)c1'},
#  {'smiles': 'CN1C(=O)[C@@H](Cc2ccc(-c3cn[nH]c3)cc2)NC(=O)c2cc(Cl)ccc21',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f41760>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f631c0>,
#   'Standard Value': 30000.0,
#   'std_smiles': 'CN1C(=O)[C@@H](Cc2ccc(-c3cn[nH]c3)cc2)NC(=O)c2cc(Cl)ccc21'},
#  {'smiles': 'COc1ccc(CNC(=O)Nc2nc(-c3ccncc3)cs2)cc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f41120>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 4.82,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f41b20>,
#   'Standard Value': 15260.0,
#   'std_smiles': 'COc1ccc(CNC(=O)Nc2nc(-c3ccncc3)cs2)cc1'},
#  {'smiles': 'O=C(NCc1ccc([N+](=O)[O-])cc1)Nc1nc(-c2ccncc2)cs1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691edd260>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 4.46,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f41d50>,
#   'Standard Value': 34550.0,
#   'std_smiles': 'O=C(NCc1ccc([N+](=O)[O-])cc1)Nc1nc(-c2ccncc2)cs1'},
#  {'smiles': 'O=C(NCc1cc(F)cc(F)c1)Nc1nc(-c2ccncc2)cs1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691edd760>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.39,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691edd2b0>,
#   'Standard Value': 4070.0,
#   'std_smiles': 'O=C(NCc1cc(F)cc(F)c1)Nc1nc(-c2ccncc2)cs1'},
#  {'smiles': 'C[C@@H](NC(=O)Nc1nc(-c2ccncc2)cs1)c1ccccc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691eddc60>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.37,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691edd7b0>,
#   'Standard Value': 43.0,
#   'std_smiles': 'C[C@@H](NC(=O)Nc1nc(-c2ccncc2)cs1)c1ccccc1'},
#  {'smiles': 'C[C@H](NC(=O)Nc1nc(-c2ccncc2)cs1)c1ccccc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691ee01c0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.45,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691eddcb0>,
#   'Standard Value': 3560.0,
#   'std_smiles': 'C[C@H](NC(=O)Nc1nc(-c2ccncc2)cs1)c1ccccc1'},
#  {'smiles': 'O=C(Nc1nc(-c2ccncc2)cs1)N1CCN(C(=O)c2ccco2)CC1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691ee06c0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 4.46,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691ee0210>,
#   'Standard Value': 35050.0,
#   'std_smiles': 'O=C(Nc1nc(-c2ccncc2)cs1)N1CCN(C(=O)c2ccco2)CC1'},
#  {'smiles': 'O=C(Nc1nc(-c2ccncc2)cs1)N1CCN(c2cccnc2)CC1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691ee0bc0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 4.85,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691ee0710>,
#   'Standard Value': 14010.0,
#   'std_smiles': 'O=C(Nc1nc(-c2ccncc2)cs1)N1CCN(c2cccnc2)CC1'},
#  {'smiles': 'O=C(NCCc1ccccc1)Nc1nc(-c2ccncc2)cs1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691ee3170>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.32,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691ee0c10>,
#   'Standard Value': 480.0,
#   'std_smiles': 'O=C(NCCc1ccccc1)Nc1nc(-c2ccncc2)cs1'},
#  {'smiles': 'CN(Cc1ccccc1)C(=O)Nc1nc(-c2ccncc2)cs1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691ee0cb0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.96,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691ee0800>,
#   'Standard Value': 110.0,
#   'std_smiles': 'CN(Cc1ccccc1)C(=O)Nc1nc(-c2ccncc2)cs1'},
#  {'smiles': 'C[C@@H]1COCCN1c1cc(-c2ccc3c(N)[nH]nc3c2)nc(N)n1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691ee0620>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 4.8,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691ee03a0>,
#   'Standard Value': 15848.93,
#   'std_smiles': 'C[C@@H]1COCCN1c1cc(-c2ccc3c(N)[nH]nc3c2)nc(N)n1'},
#  {'smiles': 'Cc1[nH]c2ncnc(-c3ccc(NC(=O)N(CCO)c4ccc(Cl)cc4)c(F)c3)c2c1C',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691ee0030>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 0,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691ee05d0>,
#   'Standard Value': nan,
#   'std_smiles': 'Cc1[nH]c2ncnc(-c3ccc(NC(=O)N(CCO)c4ccc(Cl)cc4)c(F)c3)c2c1C'},
#  {'smiles': 'CC1(C)OCC(=O)Nc2cc(Nc3nc(NCC(F)(F)F)c4occc4n3)ccc21',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691eddf80>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.24,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691ee0170>,
#   'Standard Value': 5780.0,
#   'std_smiles': 'CC1(C)OCC(=O)Nc2cc(Nc3nc(NCC(F)(F)F)c4occc4n3)ccc21'},
#  {'smiles': 'CCn1c(-c2nonc2N)nc2cncc(C(=O)N3CC[C@H](N)C3)c21',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691edd6c0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.25,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691eddda0>,
#   'Standard Value': 5.6,
#   'std_smiles': 'CCn1c(-c2nonc2N)nc2cncc(C(=O)N3CC[C@H](N)C3)c21'},
#  {'smiles': 'COc1cc(C(=O)NC(CN)c2ccccc2)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691edd0d0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.19,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691edd670>,
#   'Standard Value': 6.39,
#   'std_smiles': 'COc1cc(C(=O)NC(CN)c2ccccc2)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cc(C(=O)NC(CN2CCCC2)c2ccccc2)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f1c300>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.61,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691edd210>,
#   'Standard Value': 243.0,
#   'std_smiles': 'COc1cc(C(=O)NC(CN2CCCC2)c2ccccc2)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cc(C(=O)NCc2ccccc2F)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f53800>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.1,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f1c120>,
#   'Standard Value': 7.9,
#   'std_smiles': 'COc1cc(C(=O)NCc2ccccc2F)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cc(C(=O)NCc2cc(F)ccc2F)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f690d0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.73,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f53300>,
#   'Standard Value': 18.6,
#   'std_smiles': 'COc1cc(C(=O)NCc2cc(F)ccc2F)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cc(C(=O)N[C@H](C)c2ccccc2)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f0c800>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.23,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f69800>,
#   'Standard Value': 5.91,
#   'std_smiles': 'COc1cc(C(=O)N[C@H](C)c2ccccc2)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cc(C(=O)NCc2ccc3nc(N)sc3c2)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f29350>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 5.91,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f0c030>,
#   'Standard Value': 1240.0,
#   'std_smiles': 'COc1cc(C(=O)NCc2ccc3nc(N)sc3c2)ccc1-c1cn[nH]c1'},
#  {'smiles': 'Cc1cc(C(=O)N[C@H](C)c2ccccc2)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f1d210>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.96,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f29cb0>,
#   'Standard Value': 11.0,
#   'std_smiles': 'Cc1cc(C(=O)N[C@H](C)c2ccccc2)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cc(C(=O)NCc2cccc(NS(C)(=O)=O)c2)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f5c4e0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.61,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f1d0d0>,
#   'Standard Value': 24.6,
#   'std_smiles': 'COc1cc(C(=O)NCc2cccc(NS(C)(=O)=O)c2)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cccc([C@@H](C)NC(=O)c2ccc(-c3cn[nH]c3)c(OC)c2F)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f16925600d0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.22,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f5c300>,
#   'Standard Value': 5.98,
#   'std_smiles': 'COc1cccc([C@@H](C)NC(=O)c2ccc(-c3cn[nH]c3)c(OC)c2F)c1'},
#  {'smiles': 'COC[C@H](NC(=O)c1ccc(-c2cn[nH]c2)c(OC)c1)[C@@H](O)c1ccccc1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f9fa80>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.22,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f16925603f0>,
#   'Standard Value': 602.0,
#   'std_smiles': 'COC[C@H](NC(=O)c1ccc(-c2cn[nH]c2)c(OC)c1)[C@@H](O)c1ccccc1'},
#  {'smiles': 'COC(=O)c1cc(CNC(=O)c2ccc(-c3cn[nH]c3)c(OC)c2)ccc1F',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f72f30>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.19,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f9f580>,
#   'Standard Value': 6.53,
#   'std_smiles': 'COC(=O)c1cc(CNC(=O)c2ccc(-c3cn[nH]c3)c(OC)c2)ccc1F'},
#  {'smiles': 'COc1cccc([C@@H](C)NC(=O)c2ccc(-c3cn[nH]c3)c(C(F)(F)F)c2)c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f2dc60>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 8.15,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f06a30>,
#   'Standard Value': 7.09,
#   'std_smiles': 'COc1cccc([C@@H](C)NC(=O)c2ccc(-c3cn[nH]c3)c(C(F)(F)F)c2)c1'},
#  {'smiles': 'COc1cc(C(=O)NC(C)c2c(F)cccc2Cl)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f389e0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.78,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f2d030>,
#   'Standard Value': 16.7,
#   'std_smiles': 'COc1cc(C(=O)NC(C)c2c(F)cccc2Cl)ccc1-c1cn[nH]c1'},
#  {'smiles': 'COc1cc(C(=O)N[C@H](CNS(=O)(=O)C2CC2)c2ccccc2)ccc1-c1cn[nH]c1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f250d0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 7.95,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f38940>,
#   'Standard Value': 11.3,
#   'std_smiles': 'COc1cc(C(=O)N[C@H](CNS(=O)(=O)C2CC2)c2ccccc2)ccc1-c1cn[nH]c1'},
#  {'smiles': 'CN(C)CCOc1cc(-c2ccncc2)ccc1NC(=O)C1COc2ccc(F)cc2C1',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f3a9e0>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.98,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f25ee0>,
#   'Standard Value': 104.0,
#   'std_smiles': 'CN(C)CCOc1cc(-c2ccncc2)ccc1NC(=O)C1COc2ccc(F)cc2C1'},
#  {'smiles': 'Nc1nccc2c(S(=O)(=O)N3CCCNCC3)cccc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f3e620>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.12,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f3acb0>,
#   'Standard Value': 758.58,
#   'std_smiles': 'Nc1nccc2c(S(=O)(=O)N3CCCNCC3)cccc12'},
#  {'smiles': 'Nc1nccc2cc(O[C@H]3CCCN(Cc4ccccc4)C3)ccc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f3e580>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.11,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f3ed50>,
#   'Standard Value': 776.25,
#   'std_smiles': 'Nc1nccc2cc(O[C@H]3CCCN(Cc4ccccc4)C3)ccc12'},
#  {'smiles': 'O=c1[nH]ccc2cc(O[C@@H]3CCCNC3)ccc12',
#   'rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f41940>,
#   'source': 'rock1_chembl',
#   'pChEMBL Value': 6.17,
#   'std_rdmol': <rdkit.Chem.rdchem.Mol at 0x7f1691f64490>,
#   'Standard Value': 676.08,
#   'std_smiles': 'O=c1[nH]ccc2cc(O[C@@H]3CCCNC3)ccc12'},
#  ...]

# %%
# %%capture
# %%capture hides stderr (and maybe all output)
# same for drugbank
for m in Chem.SDMolSupplier("../data/drugbank.sdf"):
    if m:
        stdmol = standardize(m)
    else:
        continue    
    if stdmol:
        std_smiles = Chem.MolToSmiles(stdmol)
        mols.append({
         "rdmol": m,
         "std_rdmol": stdmol,
         "source": "drugbank",
         "std_smiles": std_smiles,
         "Smiles": Chem.MolToSmiles(m),
         "pChEMBL Value": 0,
         "Standard Value": np.NaN,
        })

# %%
# %%capture
with gzip.open('../ohusak/Data/actives_final.sdf.gz', 'r') as sdf:
    suppl = Chem.ForwardSDMolSupplier(sdf)
    for m in suppl:
        print(m)
        if m:
            stdmol = standardize(m)
        else:
            continue    
        if stdmol:
            std_smiles = Chem.MolToSmiles(stdmol)
            mols.append({
             "rdmol": m,
             "std_rdmol": stdmol,
             "source": "rock1_active",
             "std_smiles": std_smiles,
             "Smiles": Chem.MolToSmiles(m),
             "pChEMBL Value": 0,
             "Standard Value": np.NaN,
            })

# %%
# %%capture
with gzip.open('../ohusak/Data/decoys_final.sdf.gz', 'r') as sdf:
    suppl = Chem.ForwardSDMolSupplier(sdf)
    for m in suppl:
        print(m)
        if m:
            stdmol = standardize(m)
        else:
            continue    
        if stdmol:
            std_smiles = Chem.MolToSmiles(stdmol)
            mols.append({
             "rdmol": m,
             "std_rdmol": stdmol,
             "source": "rock1_decoy",
             "std_smiles": std_smiles,
             "Smiles": Chem.MolToSmiles(m),
             "pChEMBL Value": 0,
             "Standard Value": np.NaN,
            })

# %%
df = pd.DataFrame(mols)
df
# Out:
#                                                   smiles  \
# 0      O=C(Nc1cccc(-c2ccnc3cc(-c4ccncc4)nn23)c1)c1ccc...
# 1              C[C@@H](Nc1c(Nc2ccncc2)c(=O)c1=O)c1ccccc1
# 2             C[C@@H](N)[C@H]1CC[C@H](C(=O)Nc2ccncc2)CC1
# 3      Cc1n[nH]c2ccc(-c3cc(OC[C@@H](N)Cc4ccccc4)cnc3-...
# 4      Cc1n[nH]c2ccc(-c3cc(OC[C@@H](N)Cc4ccccc4)cnc3-...
# ...                                                  ...
# 31455                                                NaN
# 31456                                                NaN
# 31457                                                NaN
# 31458                                                NaN
# 31459                                                NaN
#
#                                                    rdmol        source  \
# 0      <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...  rock1_chembl
# 1      <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...  rock1_chembl
# 2      <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...  rock1_chembl
# 3      <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...  rock1_chembl
# 4      <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...  rock1_chembl
# ...                                                  ...           ...
# 31455  <rdkit.Chem.rdchem.Mol object at 0x000001BD9CF...   rock1_decoy
# 31456  <rdkit.Chem.rdchem.Mol object at 0x000001BD9CF...   rock1_decoy
# 31457  <rdkit.Chem.rdchem.Mol object at 0x000001BD9CF...   rock1_decoy
# 31458  <rdkit.Chem.rdchem.Mol object at 0x000001BD9CF...   rock1_decoy
# 31459  <rdkit.Chem.rdchem.Mol object at 0x000001BD9CF...   rock1_decoy
#
#        pChEMBL Value                                          std_rdmol  \
# 0               0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...
# 1               7.22  <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...
# 2               6.82  <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...
# 3               5.22  <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...
# 4               0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...
# ...              ...                                                ...
# 31455           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BD9CF...
# 31456           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BD9CF...
# 31457           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BD9CF...
# 31458           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BD9CF...
# 31459           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BD9CF...
#
#        Standard Value                                         std_smiles  \
# 0             50000.0  O=C(Nc1cccc(-c2ccnc3cc(-c4ccncc4)nn23)c1)c1ccc...
# 1                60.0          C[C@@H](Nc1c(Nc2ccncc2)c(=O)c1=O)c1ccccc1
# 2               150.0         C[C@@H](N)[C@H]1CC[C@H](C(=O)Nc2ccncc2)CC1
# 3              6000.0  Cc1n[nH]c2ccc(-c3cc(OC[C@@H](N)Cc4ccccc4)cnc3-...
# 4             10000.0  Cc1n[nH]c2ccc(-c3cc(OC[C@@H](N)Cc4ccccc4)cnc3-...
# ...               ...                                                ...
# 31455             NaN           COc1cc(/C=C/C(=O)c2c(O)cc(C)oc2=O)ccc1SC
# 31456             NaN                 COc1ccccc1CC1CCN(c2cnnc(O)c2Cl)CC1
# 31457             NaN    CN(C)S(=O)(=O)/N=C(\O)C1(c2ccc(C(C)(C)C)cc2)CC1
# 31458             NaN           CN(C)S(=O)(=O)/N=C(\O)c1cc2sc3ccccc3c2s1
# 31459             NaN           O=S(=O)(Nc1nc2cc(F)c(F)cc2s1)c1cncc(F)c1
#
#                                                   Smiles
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 31455        COc1cc(/C=C/C(=O)c2c([O-])cc(C)oc2=O)ccc1SC
# 31456              COc1ccccc1CC1CCN(c2cnnc([O-])c2Cl)CC1
# 31457  CN(C)S(=O)(=O)/N=C(\[O-])C1(c2ccc(C(C)(C)C)cc2...
# 31458        CN(C)S(=O)(=O)/N=C(\[O-])c1cc2sc3ccccc3c2s1
# 31459        O=S(=O)([N-]c1nc2cc(F)c(F)cc2s1)c1cncc(F)c1
#
# [31460 rows x 8 columns]

# %% [markdown]
# # Docking prep

# %%
def run_dockstring(target, ligand_smiles):
    """wrapper around Dockstring to return None if the process fails"""
    try:
        docking = target.dock(ligand_smiles)
        return docking
    except:
        return None, None

# %%
target = dockstring.load_target('ROCK1')
run_dockstring(target, 'CCO')
# Out:
# C:\Users\husak\anaconda3\envs\cdd\lib\site-packages\dockstring\utils.py:265: UserWarning: Incorrect rdkit version 2023.03.1 (expected 2021.03.*). You can still run docking, but be advised that the output may not match the dockstring dataset.
#   warnings.warn(message=f"Incorrect rdkit version {rdkit.__version__} "
# (None, None)

# %%
target = dockstring.load_target('ROCK1')
docking = target.dock('C1CCCC1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15492\3481264051.py in <module>
#       1 target = dockstring.load_target('ROCK1')
# ----> 2 docking = target.dock('C1CCCC1')
#
# ~\anaconda3\envs\cdd\lib\site-packages\dockstring\target.py in dock(self, smiles, pH, num_cpus, seed, verbose)
#     189         # Dock
#     190         write_mol_to_mol_file(refined_mol, ligand_mol_file)
# --> 191         convert_mol_file_to_pdbqt(ligand_mol_file, ligand_pdbqt)
#     192         self._dock_pdbqt(ligand_pdbqt, vina_logfile, vina_outfile, seed=seed, num_cpus=num_cpus)
#     193
#
# ~\anaconda3\envs\cdd\lib\site-packages\dockstring\utils.py in convert_mol_file_to_pdbqt(mol_file, pdbqt_file)
#     352     ]
#     353     # yapf: enable
# --> 354     cmd_return = subprocess.run(cmd_list, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
#     355     output = cmd_return.stdout.decode('utf-8')
#     356     logging.debug(output)
#
# ~\anaconda3\envs\cdd\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486         kwargs['stderr'] = PIPE
#     487
# --> 488     with Popen(*popenargs, **kwargs) as process:
#     489         try:
#     490             stdout, stderr = process.communicate(input, timeout=timeout)
#
# ~\anaconda3\envs\cdd\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     798                                 c2pread, c2pwrite,
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#     802             # Cleanup if the child failed starting.
#
# ~\anaconda3\envs\cdd\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1146
#    1147             if not isinstance(args, str):
# -> 1148                 args = list2cmdline(args)
#    1149
#    1150             # Process startup details
#
# ~\anaconda3\envs\cdd\lib\subprocess.py in list2cmdline(seq)
#     553             result.append(' ')
#     554
# --> 555         needquote = (" " in arg) or ("\t" in arg) or not arg
#     556         if needquote:
#     557             result.append('"')
#
# TypeError: argument of type 'WindowsPath' is not iterable

# %% [markdown]
# # Docking

# %%
# stratified sampling, 10 from each category
df_sample = df.groupby('source', group_keys=False).apply(lambda x: x.sample(min(len(x), 10)))
df_sample
# Out:
#                                                   smiles  \
# 4150                                                 NaN
# 3635                                                 NaN
# 2142                                                 NaN
# 5508                                                 NaN
# 5925                                                 NaN
# 4189                                                 NaN
# 7253                                                 NaN
# 7116                                                 NaN
# 3791                                                 NaN
# 6865                                                 NaN
# 7704                                                 NaN
# 7948                                                 NaN
# 7721                                                 NaN
# 8049                                                 NaN
# 7931                                                 NaN
# 7998                                                 NaN
# 7865                                                 NaN
# 7892                                                 NaN
# 7613                                                 NaN
# 7913                                                 NaN
# 118                 c1cc2[nH]ncc2cc1-c1cncc(N2CCCNCC2)n1
# 1184                    CC1(C)NC(=O)c2sc(-c3ccncc3)cc2N1
# 753        O=C(Nc1ccc(-c2ccncc2)cc1)N[C@@H](CO)Cc1ccccc1
# 634          CNCc1nc2cc(-c3c[nH]nc3C)sc2c(=O)[nH]1.Cl.Cl
# 528                  CN1CCCN(c2nc(-c3ccnc(N)c3)cnc2N)CC1
# 450    Cc1n[nH]c2ccc(-c3cncc(OC[C@@H](N)Cc4ccccc4)c3)...
# 618      COc1ccc(F)c(CNC(=O)c2ccc(-c3cn[nH]c3)c(OC)c2)c1
# 967    COc1cccc([C@@H](C)NC(=O)c2ccc3c(c2)OC(C)c2cncc...
# 712                        Cc1c(-c2ccncc2)sc2ccc(Cl)cc12
# 1009   COc1cc(C(=O)NC(CN2CCOCC2)c2ccccc2)ccc1-c1cn[nH]c1
# 28166                                                NaN
# 12037                                                NaN
# 19668                                                NaN
# 8506                                                 NaN
# 22947                                                NaN
# 14091                                                NaN
# 29944                                                NaN
# 20494                                                NaN
# 12984                                                NaN
# 30753                                                NaN
#
#                                                    rdmol        source  \
# 4150   <rdkit.Chem.rdchem.Mol object at 0x000001BDC86...      drugbank
# 3635   <rdkit.Chem.rdchem.Mol object at 0x000001BDC66...      drugbank
# 2142   <rdkit.Chem.rdchem.Mol object at 0x000001BDC16...      drugbank
# 5508   <rdkit.Chem.rdchem.Mol object at 0x000001BDCC6...      drugbank
# 5925   <rdkit.Chem.rdchem.Mol object at 0x000001BDCE6...      drugbank
# 4189   <rdkit.Chem.rdchem.Mol object at 0x000001BDC86...      drugbank
# 7253   <rdkit.Chem.rdchem.Mol object at 0x000001BDD36...      drugbank
# 7116   <rdkit.Chem.rdchem.Mol object at 0x000001BDD16...      drugbank
# 3791   <rdkit.Chem.rdchem.Mol object at 0x000001BDC76...      drugbank
# 6865   <rdkit.Chem.rdchem.Mol object at 0x000001BDD16...      drugbank
# 7704   <rdkit.Chem.rdchem.Mol object at 0x000001BDD47...  rock1_active
# 7948   <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...  rock1_active
# 7721   <rdkit.Chem.rdchem.Mol object at 0x000001BDD47...  rock1_active
# 8049   <rdkit.Chem.rdchem.Mol object at 0x000001BDD67...  rock1_active
# 7931   <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...  rock1_active
# 7998   <rdkit.Chem.rdchem.Mol object at 0x000001BDD67...  rock1_active
# 7865   <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...  rock1_active
# 7892   <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...  rock1_active
# 7613   <rdkit.Chem.rdchem.Mol object at 0x000001BDD47...  rock1_active
# 7913   <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...  rock1_active
# 118    <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...  rock1_chembl
# 1184   <rdkit.Chem.rdchem.Mol object at 0x000001BDBE5...  rock1_chembl
# 753    <rdkit.Chem.rdchem.Mol object at 0x000001BDBD5...  rock1_chembl
# 634    <rdkit.Chem.rdchem.Mol object at 0x000001BDBD5...  rock1_chembl
# 528    <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...  rock1_chembl
# 450    <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...  rock1_chembl
# 618    <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...  rock1_chembl
# 967    <rdkit.Chem.rdchem.Mol object at 0x000001BDBE5...  rock1_chembl
# 712    <rdkit.Chem.rdchem.Mol object at 0x000001BDBD5...  rock1_chembl
# 1009   <rdkit.Chem.rdchem.Mol object at 0x000001BDBE5...  rock1_chembl
# 28166  <rdkit.Chem.rdchem.Mol object at 0x000001BD91E...   rock1_decoy
# 12037  <rdkit.Chem.rdchem.Mol object at 0x000001BDE19...   rock1_decoy
# 19668  <rdkit.Chem.rdchem.Mol object at 0x000001BDF8B...   rock1_decoy
# 8506   <rdkit.Chem.rdchem.Mol object at 0x000001BDD67...   rock1_decoy
# 22947  <rdkit.Chem.rdchem.Mol object at 0x000001BDFFD...   rock1_decoy
# 14091  <rdkit.Chem.rdchem.Mol object at 0x000001BDE69...   rock1_decoy
# 29944  <rdkit.Chem.rdchem.Mol object at 0x000001BD98E...   rock1_decoy
# 20494  <rdkit.Chem.rdchem.Mol object at 0x000001BDFAB...   rock1_decoy
# 12984  <rdkit.Chem.rdchem.Mol object at 0x000001BDE49...   rock1_decoy
# 30753  <rdkit.Chem.rdchem.Mol object at 0x000001BD9BE...   rock1_decoy
#
#        pChEMBL Value                                          std_rdmol  \
# 4150            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDC86...
# 3635            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDC66...
# 2142            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDC16...
# 5508            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDCC6...
# 5925            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDCE6...
# 4189            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDC86...
# 7253            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD36...
# 7116            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD16...
# 3791            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDC76...
# 6865            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD16...
# 7704            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD47...
# 7948            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...
# 7721            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...
# 8049            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD67...
# 7931            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...
# 7998            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD67...
# 7865            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...
# 7892            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...
# 7613            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD47...
# 7913            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...
# 118             6.98  <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...
# 1184            7.05  <rdkit.Chem.rdchem.Mol object at 0x000001BDBE5...
# 753             5.85  <rdkit.Chem.rdchem.Mol object at 0x000001BDBD5...
# 634             6.44  <rdkit.Chem.rdchem.Mol object at 0x000001BDBD5...
# 528             4.60  <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...
# 450             7.10  <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...
# 618             7.84  <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...
# 967             7.82  <rdkit.Chem.rdchem.Mol object at 0x000001BDBE5...
# 712             4.55  <rdkit.Chem.rdchem.Mol object at 0x000001BDBD5...
# 1009            6.97  <rdkit.Chem.rdchem.Mol object at 0x000001BDBE5...
# 28166           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BD91E...
# 12037           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDE19...
# 19668           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDF8B...
# 8506            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD67...
# 22947           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDFFD...
# 14091           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDE69...
# 29944           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BD98E...
# 20494           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDFAB...
# 12984           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDE49...
# 30753           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BD9BE...
#
#        Standard Value                                         std_smiles  \
# 4150              NaN                          CCCCCCCCCCNC(=O)NC1CCCCC1
# 3635              NaN  C[C@]12CCC(=O)C[C@@H]1CC[C@@H]1[C@@H]2CC[C@]2(...
# 2142              NaN                          C=CCc1ccccc1OCC(O)CNC(C)C
# 5508              NaN     O=C(O)c1ccccc1NC(=O)N1CCC(c2ccccc2C(F)(F)F)CC1
# 5925              NaN  CCCC(=O)N[C@H]1/C(=N/OC(=O)Nc2ccccc2)O[C@H](CO...
# 4189              NaN  COc1cc[nH]c1/C=C1\C(=O)Nc2ccc(F)c(C#C[C@@H](O)...
# 7253              NaN                                FC(F)(F)COCC(F)(F)F
# 7116              NaN                                COc1ccc(CC(N)=O)cc1
# 3791              NaN                             N=C(N)c1cc2c(I)cccc2s1
# 6865              NaN  N=C(N)c1cccc(CN2CCN(S(=O)(=O)c3cc4ccc(Cl)cc4s3...
# 7704              NaN  CS(=O)(=O)c1ccc(-c2cnn(C3CC3)c(=O)c2-c2ccc(F)c...
# 7948              NaN  CS(=O)(=O)c1ccc([C@@H]2Sc3ccccc3C(=O)N2c2ccc(F...
# 7721              NaN           CC(C)(C)c1cc(C(=O)CSCC2CC2)cc2c1OCC2(C)C
# 8049              NaN     CC(C)(C)c1cc(/C=C2\OC(=O)NC2=O)cc(C(C)(C)C)c1O
# 7931              NaN   CS(=O)(=O)c1ccc(-n2cnc(Cl)c2-c2ccc3c(c2)OCO3)cc1
# 7998              NaN  CC1(C)OC(=O)/C(=N\c2ccccc2)[C@H]1c1ccc(S(C)(=O...
# 7865              NaN       NS(=O)(=O)c1ccc(/N=C/c2ccc(O)c(C(=O)O)c2)cc1
# 7892              NaN  CS(=O)(=O)c1ccc(-c2sc(Cc3ccccc3)nc2-c2ccc(F)cc...
# 7613              NaN        C[C@@]1(N2C(=O)c3ccc(N)cc3C2=O)CCC(=O)NC1=O
# 7913              NaN  CC[C@@]1(CC(=O)O)CC[C@H](Cc2ccccc2)c2c1[nH]c1c...
# 118             105.0               c1cc2[nH]ncc2cc1-c1cncc(N2CCCNCC2)n1
# 1184             90.0                   CC1(C)NC(=O)c2sc(-c3ccncc3)cc2N1
# 753            1410.0      O=C(Nc1ccc(-c2ccncc2)cc1)N[C@@H](CO)Cc1ccccc1
# 634             360.0              CNCc1nc2cc(-c3c[nH]nc3C)sc2c(=O)[nH]1
# 528           25000.0                CN1CCCN(c2nc(-c3ccnc(N)c3)cnc2N)CC1
# 450              79.0  Cc1n[nH]c2ccc(-c3cncc(OC[C@@H](N)Cc4ccccc4)c3)...
# 618              14.3    COc1ccc(F)c(CNC(=O)c2ccc(-c3cn[nH]c3)c(OC)c2)c1
# 967              15.0  COc1cccc([C@@H](C)NC(=O)c2ccc3c(c2)OC(C)c2cncc...
# 712           28000.0                      Cc1c(-c2ccncc2)sc2ccc(Cl)cc12
# 1009            107.0  COc1cc(C(=O)NC(CN2CCOCC2)c2ccccc2)ccc1-c1cn[nH]c1
# 28166             NaN   Cc1ccc(N2CCN(C(=O)c3cccc(Br)c3)[C@H](C)C2=O)cc1C
# 12037             NaN      CCNC(=O)[C@H]1CCCN(C(=O)N[C@H](C)c2ccccc2C)C1
# 19668             NaN                   ClCc1cn(C2c3ccccc3-c3ccccc32)nn1
# 8506              NaN  O=c1[nH]nc(O)c2cccc(/N=C/c3c4ccccc4cc4ccccc34)c12
# 22947             NaN         Cc1noc([C@@H]2CCCN2Cc2cnc(-c3ccccc3C)s2)n1
# 14091             NaN            COc1cccc(Oc2c[nH]nc2-c2ccc(O)c(C)c2O)c1
# 29944             NaN  CCn1cc([C@H](CC(=O)N2C[C@@H](C)O[C@H](C)C2)c2c...
# 20494             NaN  CC(=O)OCC(=O)[C@@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=...
# 12984             NaN  CCC1=C(C(=O)OC)[C@@H](c2cccc(OC)c2)N2C(/C=C(\O...
# 30753             NaN  Cc1cc(OC(=O)COc2c(F)c(F)c(F)c(F)c2F)cc2c1C(=O)...
#
#                                                   Smiles
# 4150                           CCCCCCCCCCNC(=O)NC1CCCCC1
# 3635   C[C@]12CCC(=O)C[C@@H]1CC[C@@H]1[C@@H]2CC[C@]2(...
# 2142                           C=CCc1ccccc1OCC(O)CNC(C)C
# 5508      O=C(O)c1ccccc1NC(=O)N1CCC(c2ccccc2C(F)(F)F)CC1
# 5925   CCCC(=O)N[C@H]1/C(=N/OC(=O)Nc2ccccc2)O[C@H](CO...
# 4189   COc1cc[nH]c1/C=C1\C(=O)Nc2ccc(F)c(C#C[C@@H](O)...
# 7253                                 FC(F)(F)COCC(F)(F)F
# 7116                                 COc1ccc(CC(N)=O)cc1
# 3791                         NC(=[NH2+])c1cc2c(I)cccc2s1
# 6865   N=C(N)c1cccc(CN2CCN(S(=O)(=O)c3cc4ccc(Cl)cc4s3...
# 7704   CS(=O)(=O)c1ccc(-c2cnn(C3CC3)c(=O)c2-c2ccc(F)c...
# 7948   CS(=O)(=O)c1ccc([C@@H]2Sc3ccccc3C(=O)N2c2ccc(F...
# 7721            CC(C)(C)c1cc(C(=O)CSCC2CC2)cc2c1OCC2(C)C
# 8049      CC(C)(C)c1cc(/C=C2\OC(=O)NC2=O)cc(C(C)(C)C)c1O
# 7931    CS(=O)(=O)c1ccc(-n2cnc(Cl)c2-c2ccc3c(c2)OCO3)cc1
# 7998   CC1(C)OC(=O)/C(=N\c2ccccc2)[C@H]1c1ccc(S(C)(=O...
# 7865     NS(=O)(=O)c1ccc(/N=C/c2ccc(O)c(C(=O)[O-])c2)cc1
# 7892   CS(=O)(=O)c1ccc(-c2sc(Cc3ccccc3)nc2-c2ccc(F)cc...
# 7613         C[C@@]1(N2C(=O)c3ccc(N)cc3C2=O)CCC(=O)NC1=O
# 7913   CC[C@@]1(CC(=O)[O-])CC[C@H](Cc2ccccc2)c2c1[nH]...
# 118                                                  NaN
# 1184                                                 NaN
# 753                                                  NaN
# 634                                                  NaN
# 528                                                  NaN
# 450                                                  NaN
# 618                                                  NaN
# 967                                                  NaN
# 712                                                  NaN
# 1009                                                 NaN
# 28166   Cc1ccc(N2CCN(C(=O)c3cccc(Br)c3)[C@H](C)C2=O)cc1C
# 12037      CCNC(=O)[C@H]1CCCN(C(=O)N[C@H](C)c2ccccc2C)C1
# 19668                   ClCc1cn(C2c3ccccc3-c3ccccc32)nn1
# 8506   O=c1[nH]nc([O-])c2cccc(/N=C/c3c4ccccc4cc4ccccc...
# 22947         Cc1noc([C@@H]2CCCN2Cc2cnc(-c3ccccc3C)s2)n1
# 14091            COc1cccc(Oc2c[nH]nc2-c2ccc(O)c(C)c2O)c1
# 29944  CCn1cc([C@H](CC(=O)N2C[C@@H](C)O[C@H](C)C2)c2c...
# 20494  CC(=O)OCC(=O)[C@@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=...
# 12984  CCC1=C(C(=O)OC)[C@@H](c2cccc(OC)c2)N2C(/C=C(\[...
# 30753  Cc1cc(OC(=O)COc2c(F)c(F)c(F)c(F)c2F)cc2c1C(=O)...

# %%
df_sample['rock1_dockstring_score'] = df_sample['std_smiles'].apply(lambda x: run_dockstring(target, x)[0])
df_sample
# Out:
# C:\Users\husak\anaconda3\envs\cdd\lib\site-packages\dockstring\utils.py:265: UserWarning: Incorrect rdkit version 2023.03.1 (expected 2021.03.*). You can still run docking, but be advised that the output may not match the dockstring dataset.
#   warnings.warn(message=f"Incorrect rdkit version {rdkit.__version__} "
#                                                   smiles  \
# 4150                                                 NaN
# 3635                                                 NaN
# 2142                                                 NaN
# 5508                                                 NaN
# 5925                                                 NaN
# 4189                                                 NaN
# 7253                                                 NaN
# 7116                                                 NaN
# 3791                                                 NaN
# 6865                                                 NaN
# 7704                                                 NaN
# 7948                                                 NaN
# 7721                                                 NaN
# 8049                                                 NaN
# 7931                                                 NaN
# 7998                                                 NaN
# 7865                                                 NaN
# 7892                                                 NaN
# 7613                                                 NaN
# 7913                                                 NaN
# 118                 c1cc2[nH]ncc2cc1-c1cncc(N2CCCNCC2)n1
# 1184                    CC1(C)NC(=O)c2sc(-c3ccncc3)cc2N1
# 753        O=C(Nc1ccc(-c2ccncc2)cc1)N[C@@H](CO)Cc1ccccc1
# 634          CNCc1nc2cc(-c3c[nH]nc3C)sc2c(=O)[nH]1.Cl.Cl
# 528                  CN1CCCN(c2nc(-c3ccnc(N)c3)cnc2N)CC1
# 450    Cc1n[nH]c2ccc(-c3cncc(OC[C@@H](N)Cc4ccccc4)c3)...
# 618      COc1ccc(F)c(CNC(=O)c2ccc(-c3cn[nH]c3)c(OC)c2)c1
# 967    COc1cccc([C@@H](C)NC(=O)c2ccc3c(c2)OC(C)c2cncc...
# 712                        Cc1c(-c2ccncc2)sc2ccc(Cl)cc12
# 1009   COc1cc(C(=O)NC(CN2CCOCC2)c2ccccc2)ccc1-c1cn[nH]c1
# 28166                                                NaN
# 12037                                                NaN
# 19668                                                NaN
# 8506                                                 NaN
# 22947                                                NaN
# 14091                                                NaN
# 29944                                                NaN
# 20494                                                NaN
# 12984                                                NaN
# 30753                                                NaN
#
#                                                    rdmol        source  \
# 4150   <rdkit.Chem.rdchem.Mol object at 0x000001BDC86...      drugbank
# 3635   <rdkit.Chem.rdchem.Mol object at 0x000001BDC66...      drugbank
# 2142   <rdkit.Chem.rdchem.Mol object at 0x000001BDC16...      drugbank
# 5508   <rdkit.Chem.rdchem.Mol object at 0x000001BDCC6...      drugbank
# 5925   <rdkit.Chem.rdchem.Mol object at 0x000001BDCE6...      drugbank
# 4189   <rdkit.Chem.rdchem.Mol object at 0x000001BDC86...      drugbank
# 7253   <rdkit.Chem.rdchem.Mol object at 0x000001BDD36...      drugbank
# 7116   <rdkit.Chem.rdchem.Mol object at 0x000001BDD16...      drugbank
# 3791   <rdkit.Chem.rdchem.Mol object at 0x000001BDC76...      drugbank
# 6865   <rdkit.Chem.rdchem.Mol object at 0x000001BDD16...      drugbank
# 7704   <rdkit.Chem.rdchem.Mol object at 0x000001BDD47...  rock1_active
# 7948   <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...  rock1_active
# 7721   <rdkit.Chem.rdchem.Mol object at 0x000001BDD47...  rock1_active
# 8049   <rdkit.Chem.rdchem.Mol object at 0x000001BDD67...  rock1_active
# 7931   <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...  rock1_active
# 7998   <rdkit.Chem.rdchem.Mol object at 0x000001BDD67...  rock1_active
# 7865   <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...  rock1_active
# 7892   <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...  rock1_active
# 7613   <rdkit.Chem.rdchem.Mol object at 0x000001BDD47...  rock1_active
# 7913   <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...  rock1_active
# 118    <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...  rock1_chembl
# 1184   <rdkit.Chem.rdchem.Mol object at 0x000001BDBE5...  rock1_chembl
# 753    <rdkit.Chem.rdchem.Mol object at 0x000001BDBD5...  rock1_chembl
# 634    <rdkit.Chem.rdchem.Mol object at 0x000001BDBD5...  rock1_chembl
# 528    <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...  rock1_chembl
# 450    <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...  rock1_chembl
# 618    <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...  rock1_chembl
# 967    <rdkit.Chem.rdchem.Mol object at 0x000001BDBE5...  rock1_chembl
# 712    <rdkit.Chem.rdchem.Mol object at 0x000001BDBD5...  rock1_chembl
# 1009   <rdkit.Chem.rdchem.Mol object at 0x000001BDBE5...  rock1_chembl
# 28166  <rdkit.Chem.rdchem.Mol object at 0x000001BD91E...   rock1_decoy
# 12037  <rdkit.Chem.rdchem.Mol object at 0x000001BDE19...   rock1_decoy
# 19668  <rdkit.Chem.rdchem.Mol object at 0x000001BDF8B...   rock1_decoy
# 8506   <rdkit.Chem.rdchem.Mol object at 0x000001BDD67...   rock1_decoy
# 22947  <rdkit.Chem.rdchem.Mol object at 0x000001BDFFD...   rock1_decoy
# 14091  <rdkit.Chem.rdchem.Mol object at 0x000001BDE69...   rock1_decoy
# 29944  <rdkit.Chem.rdchem.Mol object at 0x000001BD98E...   rock1_decoy
# 20494  <rdkit.Chem.rdchem.Mol object at 0x000001BDFAB...   rock1_decoy
# 12984  <rdkit.Chem.rdchem.Mol object at 0x000001BDE49...   rock1_decoy
# 30753  <rdkit.Chem.rdchem.Mol object at 0x000001BD9BE...   rock1_decoy
#
#        pChEMBL Value                                          std_rdmol  \
# 4150            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDC86...
# 3635            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDC66...
# 2142            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDC16...
# 5508            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDCC6...
# 5925            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDCE6...
# 4189            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDC86...
# 7253            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD36...
# 7116            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD16...
# 3791            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDC76...
# 6865            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD16...
# 7704            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD47...
# 7948            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...
# 7721            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...
# 8049            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD67...
# 7931            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...
# 7998            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD67...
# 7865            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...
# 7892            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...
# 7613            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD47...
# 7913            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD57...
# 118             6.98  <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...
# 1184            7.05  <rdkit.Chem.rdchem.Mol object at 0x000001BDBE5...
# 753             5.85  <rdkit.Chem.rdchem.Mol object at 0x000001BDBD5...
# 634             6.44  <rdkit.Chem.rdchem.Mol object at 0x000001BDBD5...
# 528             4.60  <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...
# 450             7.10  <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...
# 618             7.84  <rdkit.Chem.rdchem.Mol object at 0x000001BDBC5...
# 967             7.82  <rdkit.Chem.rdchem.Mol object at 0x000001BDBE5...
# 712             4.55  <rdkit.Chem.rdchem.Mol object at 0x000001BDBD5...
# 1009            6.97  <rdkit.Chem.rdchem.Mol object at 0x000001BDBE5...
# 28166           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BD91E...
# 12037           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDE19...
# 19668           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDF8B...
# 8506            0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDD67...
# 22947           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDFFD...
# 14091           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDE69...
# 29944           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BD98E...
# 20494           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDFAB...
# 12984           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BDE49...
# 30753           0.00  <rdkit.Chem.rdchem.Mol object at 0x000001BD9BE...
#
#        Standard Value                                         std_smiles  \
# 4150              NaN                          CCCCCCCCCCNC(=O)NC1CCCCC1
# 3635              NaN  C[C@]12CCC(=O)C[C@@H]1CC[C@@H]1[C@@H]2CC[C@]2(...
# 2142              NaN                          C=CCc1ccccc1OCC(O)CNC(C)C
# 5508              NaN     O=C(O)c1ccccc1NC(=O)N1CCC(c2ccccc2C(F)(F)F)CC1
# 5925              NaN  CCCC(=O)N[C@H]1/C(=N/OC(=O)Nc2ccccc2)O[C@H](CO...
# 4189              NaN  COc1cc[nH]c1/C=C1\C(=O)Nc2ccc(F)c(C#C[C@@H](O)...
# 7253              NaN                                FC(F)(F)COCC(F)(F)F
# 7116              NaN                                COc1ccc(CC(N)=O)cc1
# 3791              NaN                             N=C(N)c1cc2c(I)cccc2s1
# 6865              NaN  N=C(N)c1cccc(CN2CCN(S(=O)(=O)c3cc4ccc(Cl)cc4s3...
# 7704              NaN  CS(=O)(=O)c1ccc(-c2cnn(C3CC3)c(=O)c2-c2ccc(F)c...
# 7948              NaN  CS(=O)(=O)c1ccc([C@@H]2Sc3ccccc3C(=O)N2c2ccc(F...
# 7721              NaN           CC(C)(C)c1cc(C(=O)CSCC2CC2)cc2c1OCC2(C)C
# 8049              NaN     CC(C)(C)c1cc(/C=C2\OC(=O)NC2=O)cc(C(C)(C)C)c1O
# 7931              NaN   CS(=O)(=O)c1ccc(-n2cnc(Cl)c2-c2ccc3c(c2)OCO3)cc1
# 7998              NaN  CC1(C)OC(=O)/C(=N\c2ccccc2)[C@H]1c1ccc(S(C)(=O...
# 7865              NaN       NS(=O)(=O)c1ccc(/N=C/c2ccc(O)c(C(=O)O)c2)cc1
# 7892              NaN  CS(=O)(=O)c1ccc(-c2sc(Cc3ccccc3)nc2-c2ccc(F)cc...
# 7613              NaN        C[C@@]1(N2C(=O)c3ccc(N)cc3C2=O)CCC(=O)NC1=O
# 7913              NaN  CC[C@@]1(CC(=O)O)CC[C@H](Cc2ccccc2)c2c1[nH]c1c...
# 118             105.0               c1cc2[nH]ncc2cc1-c1cncc(N2CCCNCC2)n1
# 1184             90.0                   CC1(C)NC(=O)c2sc(-c3ccncc3)cc2N1
# 753            1410.0      O=C(Nc1ccc(-c2ccncc2)cc1)N[C@@H](CO)Cc1ccccc1
# 634             360.0              CNCc1nc2cc(-c3c[nH]nc3C)sc2c(=O)[nH]1
# 528           25000.0                CN1CCCN(c2nc(-c3ccnc(N)c3)cnc2N)CC1
# 450              79.0  Cc1n[nH]c2ccc(-c3cncc(OC[C@@H](N)Cc4ccccc4)c3)...
# 618              14.3    COc1ccc(F)c(CNC(=O)c2ccc(-c3cn[nH]c3)c(OC)c2)c1
# 967              15.0  COc1cccc([C@@H](C)NC(=O)c2ccc3c(c2)OC(C)c2cncc...
# 712           28000.0                      Cc1c(-c2ccncc2)sc2ccc(Cl)cc12
# 1009            107.0  COc1cc(C(=O)NC(CN2CCOCC2)c2ccccc2)ccc1-c1cn[nH]c1
# 28166             NaN   Cc1ccc(N2CCN(C(=O)c3cccc(Br)c3)[C@H](C)C2=O)cc1C
# 12037             NaN      CCNC(=O)[C@H]1CCCN(C(=O)N[C@H](C)c2ccccc2C)C1
# 19668             NaN                   ClCc1cn(C2c3ccccc3-c3ccccc32)nn1
# 8506              NaN  O=c1[nH]nc(O)c2cccc(/N=C/c3c4ccccc4cc4ccccc34)c12
# 22947             NaN         Cc1noc([C@@H]2CCCN2Cc2cnc(-c3ccccc3C)s2)n1
# 14091             NaN            COc1cccc(Oc2c[nH]nc2-c2ccc(O)c(C)c2O)c1
# 29944             NaN  CCn1cc([C@H](CC(=O)N2C[C@@H](C)O[C@H](C)C2)c2c...
# 20494             NaN  CC(=O)OCC(=O)[C@@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=...
# 12984             NaN  CCC1=C(C(=O)OC)[C@@H](c2cccc(OC)c2)N2C(/C=C(\O...
# 30753             NaN  Cc1cc(OC(=O)COc2c(F)c(F)c(F)c(F)c2F)cc2c1C(=O)...
#
#                                                   Smiles  \
# 4150                           CCCCCCCCCCNC(=O)NC1CCCCC1
# 3635   C[C@]12CCC(=O)C[C@@H]1CC[C@@H]1[C@@H]2CC[C@]2(...
# 2142                           C=CCc1ccccc1OCC(O)CNC(C)C
# 5508      O=C(O)c1ccccc1NC(=O)N1CCC(c2ccccc2C(F)(F)F)CC1
# 5925   CCCC(=O)N[C@H]1/C(=N/OC(=O)Nc2ccccc2)O[C@H](CO...
# 4189   COc1cc[nH]c1/C=C1\C(=O)Nc2ccc(F)c(C#C[C@@H](O)...
# 7253                                 FC(F)(F)COCC(F)(F)F
# 7116                                 COc1ccc(CC(N)=O)cc1
# 3791                         NC(=[NH2+])c1cc2c(I)cccc2s1
# 6865   N=C(N)c1cccc(CN2CCN(S(=O)(=O)c3cc4ccc(Cl)cc4s3...
# 7704   CS(=O)(=O)c1ccc(-c2cnn(C3CC3)c(=O)c2-c2ccc(F)c...
# 7948   CS(=O)(=O)c1ccc([C@@H]2Sc3ccccc3C(=O)N2c2ccc(F...
# 7721            CC(C)(C)c1cc(C(=O)CSCC2CC2)cc2c1OCC2(C)C
# 8049      CC(C)(C)c1cc(/C=C2\OC(=O)NC2=O)cc(C(C)(C)C)c1O
# 7931    CS(=O)(=O)c1ccc(-n2cnc(Cl)c2-c2ccc3c(c2)OCO3)cc1
# 7998   CC1(C)OC(=O)/C(=N\c2ccccc2)[C@H]1c1ccc(S(C)(=O...
# 7865     NS(=O)(=O)c1ccc(/N=C/c2ccc(O)c(C(=O)[O-])c2)cc1
# 7892   CS(=O)(=O)c1ccc(-c2sc(Cc3ccccc3)nc2-c2ccc(F)cc...
# 7613         C[C@@]1(N2C(=O)c3ccc(N)cc3C2=O)CCC(=O)NC1=O
# 7913   CC[C@@]1(CC(=O)[O-])CC[C@H](Cc2ccccc2)c2c1[nH]...
# 118                                                  NaN
# 1184                                                 NaN
# 753                                                  NaN
# 634                                                  NaN
# 528                                                  NaN
# 450                                                  NaN
# 618                                                  NaN
# 967                                                  NaN
# 712                                                  NaN
# 1009                                                 NaN
# 28166   Cc1ccc(N2CCN(C(=O)c3cccc(Br)c3)[C@H](C)C2=O)cc1C
# 12037      CCNC(=O)[C@H]1CCCN(C(=O)N[C@H](C)c2ccccc2C)C1
# 19668                   ClCc1cn(C2c3ccccc3-c3ccccc32)nn1
# 8506   O=c1[nH]nc([O-])c2cccc(/N=C/c3c4ccccc4cc4ccccc...
# 22947         Cc1noc([C@@H]2CCCN2Cc2cnc(-c3ccccc3C)s2)n1
# 14091            COc1cccc(Oc2c[nH]nc2-c2ccc(O)c(C)c2O)c1
# 29944  CCn1cc([C@H](CC(=O)N2C[C@@H](C)O[C@H](C)C2)c2c...
# 20494  CC(=O)OCC(=O)[C@@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=...
# 12984  CCC1=C(C(=O)OC)[C@@H](c2cccc(OC)c2)N2C(/C=C(\[...
# 30753  Cc1cc(OC(=O)COc2c(F)c(F)c(F)c(F)c2F)cc2c1C(=O)...
#
#       rock1_dockstring_score
# 4150                    None
# 3635                    None
# 2142                    None
# 5508                    None
# 5925                    None
# 4189                    None
# 7253                    None
# 7116                    None
# 3791                    None
# 6865                    None
# 7704                    None
# 7948                    None
# 7721                    None
# 8049                    None
# 7931                    None
# 7998                    None
# 7865                    None
# 7892                    None
# 7613                    None
# 7913                    None
# 118                     None
# 1184                    None
# 753                     None
# 634                     None
# 528                     None
# 450                     None
# 618                     None
# 967                     None
# 712                     None
# 1009                    None
# 28166                   None
# 12037                   None
# 19668                   None
# 8506                    None
# 22947                   None
# 14091                   None
# 29944                   None
# 20494                   None
# 12984                   None
# 30753                   None

# %%
df_sample2 = df.groupby('source', group_keys=False).apply(lambda x: x.sample(min(len(x), 30)))
df_sample2['rock1_dockstring_score'] = df_sample2['std_smiles'].apply(lambda x: run_dockstring(target, x)[0])
df_sample2
# Out:
# C:\Users\husak\anaconda3\envs\cdd\lib\site-packages\dockstring\utils.py:265: UserWarning: Incorrect rdkit version 2023.03.1 (expected 2021.03.*). You can still run docking, but be advised that the output may not match the dockstring dataset.
#   warnings.warn(message=f"Incorrect rdkit version {rdkit.__version__} "
# [13:42:24] Explicit valence for atom # 1 O, 3, is greater than permitted
#       smiles                                              rdmol       source  \
# 4123     NaN  <rdkit.Chem.rdchem.Mol object at 0x000001BDC86...     drugbank
# 2302     NaN  <rdkit.Chem.rdchem.Mol object at 0x000001BDC16...     drugbank
# 1931     NaN  <rdkit.Chem.rdchem.Mol object at 0x000001BDC06...     drugbank
# 6882     NaN  <rdkit.Chem.rdchem.Mol object at 0x000001BDD16...     drugbank
# 6182     NaN  <rdkit.Chem.rdchem.Mol object at 0x000001BDCE6...     drugbank
# ...      ...                                                ...          ...
# 22169    NaN  <rdkit.Chem.rdchem.Mol object at 0x000001BDFFC...  rock1_decoy
# 12557    NaN  <rdkit.Chem.rdchem.Mol object at 0x000001BDE29...  rock1_decoy
# 12833    NaN  <rdkit.Chem.rdchem.Mol object at 0x000001BDE39...  rock1_decoy
# 25552    NaN  <rdkit.Chem.rdchem.Mol object at 0x000001BDFFF...  rock1_decoy
# 21250    NaN  <rdkit.Chem.rdchem.Mol object at 0x000001BDFDB...  rock1_decoy
#
#        pChEMBL Value                                          std_rdmol  \
# 4123             0.0  <rdkit.Chem.rdchem.Mol object at 0x000001BDC86...
# 2302             0.0  <rdkit.Chem.rdchem.Mol object at 0x000001BDC16...
# 1931             0.0  <rdkit.Chem.rdchem.Mol object at 0x000001BDC06...
# 6882             0.0  <rdkit.Chem.rdchem.Mol object at 0x000001BDD16...
# 6182             0.0  <rdkit.Chem.rdchem.Mol object at 0x000001BDCE6...
# ...              ...                                                ...
# 22169            0.0  <rdkit.Chem.rdchem.Mol object at 0x000001BDFFC...
# 12557            0.0  <rdkit.Chem.rdchem.Mol object at 0x000001BDE29...
# 12833            0.0  <rdkit.Chem.rdchem.Mol object at 0x000001BDE39...
# 25552            0.0  <rdkit.Chem.rdchem.Mol object at 0x000001BDFFF...
# 21250            0.0  <rdkit.Chem.rdchem.Mol object at 0x000001BDFDB...
#
#        Standard Value                                         std_smiles  \
# 4123              NaN                      N[C@H](C(=O)O)[C@@H](O)C(=O)O
# 2302              NaN                         CCN(CC)CCNC(=O)c1ccc(N)cc1
# 1931              NaN  N=c1nc(O)c2c(CCc3ccc(C(=O)N[C@@H](CCC(=O)O)C(=...
# 6882              NaN     COC(=O)[C@H](Cc1ccc(Br)cc1)NC(=O)CCCCCCC(=O)NO
# 6182              NaN                       COc1ccc2[nH]cc(CCC(=O)O)c2c1
# ...               ...                                                ...
# 22169             NaN     CC[C@H](C)[C@H](NC(=O)Nc1c(C)cc(Br)cc1C)C(=O)O
# 12557             NaN   Cc1ccc(NC(=O)c2ccc(OC[C@H]3CCCO3)c(Br)c2)c(Br)c1
# 12833             NaN           Cc1cc(Br)c(-n2nnc(C(=O)O)c2C2CC2)c(Br)c1
# 25552             NaN          N#C[C@H](C(=O)c1cc2c(s1)CCCC2)c1cccc(F)c1
# 21250             NaN  Cc1cc(C)c([C@H]2Nc3c(Cl)cc(Cl)cc3[C@H]3C=CC[C@...
#
#                                                   Smiles  \
# 4123                       N[C@H](C(=O)O)[C@@H](O)C(=O)O
# 2302                          CCN(CC)CCNC(=O)c1ccc(N)cc1
# 1931   N=c1nc(O)c2c(CCc3ccc(C(=O)N[C@@H](CCC(=O)O)C(=...
# 6882      COC(=O)[C@H](Cc1ccc(Br)cc1)NC(=O)CCCCCCC(=O)NO
# 6182                        COc1ccc2[nH]cc(CCC(=O)O)c2c1
# ...                                                  ...
# 22169  CC[C@H](C)[C@H](NC(=O)Nc1c(C)cc(Br)cc1C)C(=O)[O-]
# 12557   Cc1ccc(NC(=O)c2ccc(OC[C@H]3CCCO3)c(Br)c2)c(Br)c1
# 12833        Cc1cc(Br)c(-n2nnc(C(=O)[O-])c2C2CC2)c(Br)c1
# 25552          N#C[C@H](C(=O)c1cc2c(s1)CCCC2)c1cccc(F)c1
# 21250  Cc1cc(C)c([C@H]2Nc3c(Cl)cc(Cl)cc3[C@H]3C=CC[C@...
#
#       rock1_dockstring_score
# 4123                    None
# 2302                    None
# 1931                    None
# 6882                    None
# 6182                    None
# ...                      ...
# 22169                   None
# 12557                   None
# 12833                   None
# 25552                   None
# 21250                   None
#
# [120 rows x 9 columns]
